# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** *Replace this cell with your problem statement.*

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def mean(numbers):
    return sum(numbers)/len(numbers)

# %%
mean([1, 3, 5, 7])
# Out:
# 4.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def std_dev(numbers):
    n = len(numbers)
    mean = sum(numbers) / n
    var = sum((i - mean) ** 2 for i in numbers) / n
    std_dev = var ** 0.5
    return std_dev

# %%
std_dev([1, 3, 5, 7])
# Out:
# 2.23606797749979

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def perc_to_float(string):
    string_num = string.replace("%","")
    return float(string_num) / 100

# %%
perc_to_float('30.5%')
# Out:
# 0.305

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import altair as alt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
# %matplotlib inline
import altair as alt
import statsmodels.api as sm
from IPython.display import Image

#import chart_studio.plotly as py
#import plotly.graph_objs as go 
#import cufflinks as cf
#from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
#init_notebook_mode(connected=True)

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# ### 1. Import and display Datasets

# %%
# Import all datasets. 
act17 = pd.read_csv("../data/act_2017.csv")
act18 = pd.read_csv("../data/act_2018.csv")
act19 = pd.read_csv("../data/act_2019.csv")
sat17 = pd.read_csv("../data/sat_2017.csv")
sat18 = pd.read_csv("../data/sat_2018.csv")
sat19 = pd.read_csv("../data/sat_2019.csv")
act19_ca = pd.read_csv("../data/act_2019_ca.csv")
sat19_ca = pd.read_csv("../data/sat_2019_ca.csv")

#Import US states GDP data from source https://apps.bea.gov/regional/downloadzip.cfm
states_gdp = pd.read_csv("../data/states_data_1997_2021.csv")

#Import median household income from source https://nces.ed.gov/programs/digest/d20/tables/dt20_102.30.asp
states_income = pd.read_csv("../data/states_income.csv")

#Import percentage of people in poverty by State using 3-Year average (2017-2019) from source https://www.census.gov/data/tables/2020/demo/income-poverty/p60-270.html
states_poverty = pd.read_csv("../data/states_poverty.csv")

states_pop = pd.read_csv("../data/population.csv")

# %%
states_pop.head(3)
# Out:
#    STATE     NAME  POPESTIMATE2019
# 0      1  Alabama          4903185
# 1      2   Alaska           731545
# 2      4  Arizona          7278717

# %%
states_pop.dtypes
# Out:
# STATE               int64
# NAME               object
# POPESTIMATE2019     int64
# dtype: object

# %%
states_pop.drop(columns='STATE', inplace=True)
states_pop.head(3)
# Out:
#       NAME  POPESTIMATE2019
# 0  Alabama          4903185
# 1   Alaska           731545
# 2  Arizona          7278717

# %%
#Rename columns heading
states_pop.rename(columns = {'NAME':'state', 'POPESTIMATE2019':'pop19'}, inplace = True)
states_pop.head(3)
# Out:
#      state    pop19
# 0  Alabama  4903185
# 1   Alaska   731545
# 2  Arizona  7278717

# %%
states_pop.head()
# Out:
#         state     pop19
# 0     Alabama   4903185
# 1      Alaska    731545
# 2     Arizona   7278717
# 3    Arkansas   3017804
# 4  California  39512223

# %%
act19.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
sat19.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %% [markdown]
# ### 2. Check for missing values

# %%
act19.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
sat19.isnull().sum()
# Out:
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %% [markdown]
# ### 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).

# %% [markdown]
# **a) Checking the Min/Max Values in ACT 2017 - 2019**
#
# The range of scores for the ACT should be between 1-36.

# %%
print(act17.min(), act17.max())
# Out:
# State            Alabama
# Participation        60%
# English             16.3
# Math                18.0
# Reading             18.1
# Science              2.3
# Composite           17.8
# dtype: object State            Wyoming
# Participation        98%
# English             25.5
# Math                25.3
# Reading             26.0
# Science             24.9
# Composite           25.5
# dtype: object

# %%
print(act18.min(), act18.max())
# Out:
# State            Alabama
# Participation       100%
# Composite           17.7
# dtype: object State            Wyoming
# Participation        99%
# Composite           25.6
# dtype: object

# %%
print(act19.min(), act19.max())
# Out:
# State            Alabama
# Participation       100%
# Composite           17.9
# dtype: object State            Wyoming
# Participation        96%
# Composite           25.5
# dtype: object

# %% [markdown]
# **b) Checking the Min/Max Values in SAT 2017 - 2019**
#
# The range of scores for the SAT should be between 200-800.

# %%
print(sat17.min(), sat17.max())
# Out:
# State                                 Alabama
# Participation                             10%
# Evidence-Based Reading and Writing        482
# Math                                       52
# Total                                     950
# dtype: object State                                 Wyoming
# Participation                             96%
# Evidence-Based Reading and Writing        644
# Math                                      651
# Total                                    1295
# dtype: object

# %%
print(sat18.min(), sat18.max())
# Out:
# State                                 Alabama
# Participation                             10%
# Evidence-Based Reading and Writing        480
# Math                                      480
# Total                                     977
# dtype: object State                                 Wyoming
# Participation                             99%
# Evidence-Based Reading and Writing        643
# Math                                      655
# Total                                    1298
# dtype: object

# %%
print(sat19.min(), sat19.max())
# Out:
# State                 Alabama
# Participation Rate       100%
# EBRW                      483
# Math                      445
# Total                     935
# dtype: object State                 Wyoming
# Participation Rate          —
# EBRW                      636
# Math                      648
# Total                    1284
# dtype: object

# %% [markdown]
# ### 4. Fix any errors identified in Steps 2-3

# %% [markdown]
# From step 3, there seems to be an error with the SAT 2017 min Math score of 52 which is out of the range of 200 - 800.

# %%
sat17.sort_values(['Math']).head(1)
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %% [markdown]
# To get the correct Math score, we subtract the writing score from the total score.
# The correct Math score for the State of Maryland should be 524.

# %%
# Assign the new value to the state of Maryland
sat17.loc[20,'Math'] = 524

# Check the score to make sure value has been replaced
sat17['Math'][20]
# Out:
# 524

# %% [markdown]
# ### 5. Display data types of each feature

# %%
act17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
act18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
act19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
sat17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %% [markdown]
# ### 6. Fix any incorrect data types

# %% [markdown]
# **a) Fix data type for ACT 2017**

# %%
#Change from Percentage to float
act17['Participation'] = act17['Participation'].map(perc_to_float)

#Replace Wyoming Composite from 20.2x to 20.2
act17['Composite'] = act17['Composite'].replace(['20.2x'],20.2)
act17['Composite'] = pd.to_numeric(act17['Composite'])

# %%
act17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %% [markdown]
# **b) Fix data type for ACT 2018**

# %%
#Change from Percentage to float
act18['Participation'] = act18['Participation'].map(perc_to_float)

# %%
act18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   Composite      52 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# **c) Fix data type for ACT 2019**

# %%
#Change from Percentage to float
act19['Participation'] = act19['Participation'].map(perc_to_float)

# %%
act19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   Composite      52 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# **d) Fix data type for SAT 2017**

# %%
#Change from Percentage to float
sat17['Participation'] = sat17['Participation'].map(perc_to_float)

# %%
sat17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# **e) Fix data type for SAT 2018**

# %%
#Change from Percentage to float
sat18['Participation'] = sat18['Participation'].map(perc_to_float)

# %%
sat18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# **f) Fix data type for SAT 2019**

# %%
#Removal of Virgin island and Puerto Rico
sat19.drop(sat19[sat19['State']=="Puerto Rico"].index, inplace=True)
sat19.drop(sat19[sat19['State']=="Virgin Islands"].index, inplace=True)

#Change from Percentage to float
sat19['Participation Rate'] = sat19['Participation Rate'].map(perc_to_float)

# %%
sat19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               51 non-null     object
#  1   Participation Rate  51 non-null     float64
#  2   EBRW                51 non-null     int64
#  3   Math                51 non-null     int64
#  4   Total               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.4+ KB

# %% [markdown]
# ### 7. Rename Columns

# %% [markdown]
# For ACT 2017 to 2019

# %%
#Change column names to lowercase.
act17_columns_list = [
    'state',
    'act17_part',
    'act17_eng',
    'act17_math',
    'act17_read',
    'act17_sci',
    'act17_comp'
]

act18_columns_list = [
    'state',
    'act18_part',
    'act18_comp'
]

act19_columns_list = [
    'state',
    'act19_part',
    'act19_comp'
]

act17.columns = act17_columns_list
act18.columns = act18_columns_list
act19.columns = act19_columns_list

# %% [markdown]
# For SAT 2017 to 2019

# %%
#Change column names to lowercase.
sat17_columns_list = [
    'state',
    'sat17_part',
    'sat17_ebrw',
    'sat17_math',
    'sat17_total'
]

sat18_columns_list = [
    'state',
    'sat18_part',
    'sat18_ebrw',
    'sat18_math',
    'sat18_total'
]

sat19_columns_list = [
    'state',
    'sat19_part',
    'sat19_ebrw',
    'sat19_math',
    'sat19_total'
]

sat17.columns = sat17_columns_list
sat18.columns = sat18_columns_list
sat19.columns = sat19_columns_list

# %% [markdown]
# ### 8. Drop unnecesary rows

# %% [markdown]
# For ACT 2017

# %%
#Check for duplicate entries
duplicateRowsDF = act17[act17.duplicated()]
print(duplicateRowsDF)
# Out:
# Empty DataFrame
# Columns: [state, act17_part, act17_eng, act17_math, act17_read, act17_sci, act17_comp]
# Index: []

# %%
#Remove "National" as it's not a  state
act17.drop(act17[act17['state']=="National"].index, inplace=True)
#Reset and drop index
act17 = act17.reset_index(drop = True)

# %% [markdown]
# For ACT 2018

# %%
#Check for duplicate entries
duplicateRowsDF = act18[act18.duplicated()]
print(duplicateRowsDF)
# Out:
#     state  act18_part  act18_comp
# 20  Maine        0.07        24.0

# %%
#Changing "District of columbia" to "District of Columbia"
act18['state'] = act18['state'].replace(['District of columbia'],'District of Columbia')

#Drop duplicates
act18 = act18.drop_duplicates()

#Reset index
act18 = act18.reset_index(drop = True)

# %% [markdown]
# For ACT 2019

# %%
#Check for duplicate entries
duplicateRowsDF = act19[act19.duplicated()]
print(duplicateRowsDF)
# Out:
# Empty DataFrame
# Columns: [state, act19_part, act19_comp]
# Index: []

# %%
#Remove National row from act19
act19.drop(act19[act19['state']=="National"].index, inplace=True)

#Reset index
act19 = act19.reset_index(drop = True)

# %% [markdown]
# For SAT 2017

# %%
#Check for duplicate entries
duplicateRowsDF = sat17[sat17.duplicated()]
print(duplicateRowsDF)
# Out:
# Empty DataFrame
# Columns: [state, sat17_part, sat17_ebrw, sat17_math, sat17_total]
# Index: []

# %% [markdown]
# For SAT 2018

# %%
#Check for duplicate entries
duplicateRowsDF = sat18[sat18.duplicated()]
print(duplicateRowsDF)
# Out:
# Empty DataFrame
# Columns: [state, sat18_part, sat18_ebrw, sat18_math, sat18_total]
# Index: []

# %% [markdown]
# For SAT 2019

# %%
#Check for duplicate entries
duplicateRowsDF = sat19[sat19.duplicated()]
print(duplicateRowsDF)
# Out:
# Empty DataFrame
# Columns: [state, sat19_part, sat19_ebrw, sat19_math, sat19_total]
# Index: []

# %% [markdown]
# ### 9. Merge dataframes that can be  merged

# %%
#Merge ACT and SAT datasets for 2017, 2018 and 2019.

sat_act_17 = sat17.merge(act17, how = "outer", on = "state")
sat_act_18 = sat18.merge(act18, how = "outer", on = "state")
sat_act_19 = sat19.merge(act19, how = "outer", on = "state")

all_sat_act = pd.merge(pd.merge(sat_act_17,sat_act_18, on = 'state'), sat_act_19, on = 'state')

# %%
all_sat_act.shape
# Out:
# (51, 23)

# %%
all_sat_act.head()
# Out:
#         state  sat17_part  sat17_ebrw  sat17_math  sat17_total  act17_part  \
# 0     Alabama        0.05         593         572         1165        1.00
# 1      Alaska        0.38         547         533         1080        0.65
# 2     Arizona        0.30         563         553         1116        0.62
# 3    Arkansas        0.03         614         594         1208        1.00
# 4  California        0.53         531         524         1055        0.31
#
#    act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  sat18_total  \
# 0       18.9        18.4        19.7       19.4  ...         571         1166
# 1       18.7        19.8        20.4       19.9  ...         544         1106
# 2       18.6        19.8        20.1       19.8  ...         572         1149
# 3       18.9        19.0        19.7       19.5  ...         576         1169
# 4       22.5        22.7        23.1       22.2  ...         536         1076
#
# ...

# %% [markdown]
# ### 10. Perform any additional cleaning

# %% [markdown]
# *Clean dataset for ACT CA 2019*

# %% [markdown]
# *Clean dataset for SAT CA 2019*

# %% [markdown]
# ### Cleaning datasets for States' median household income, poverty and GDP

# %% [markdown]
# *Cleaning median household income*

# %%
states_income.head()
# Out:
#         State    2017    2018    2019
# 0     Alabama  50,200  50,800  51,700
# 1      Alaska  76,300  75,700  75,500
# 2     Arizona  59,000  60,300  62,100
# 3    Arkansas  47,800  47,900  49,000
# 4  California  74,900  76,600  80,400

# %%
#Remove commas
states_income = states_income.replace(',','', regex=True)

#Change columns name
states_income.rename(columns = {'State':'state', '2017':'income17', '2018':'income18','2019':'income19'}, inplace = True)

#Change data type to float
states_income[['income17','income18','income19']] = states_income[['income17','income18','income19']].astype(float)

#Check for duplicate rows
duplicateRowsDF = states_income[states_income.duplicated()]
print(duplicateRowsDF)

#Reset index
states_income = states_income.reset_index(drop = True)

states_income.info()
# Out:
# Empty DataFrame
# Columns: [state, income17, income18, income19]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   state     51 non-null     object
#  1   income17  51 non-null     float64
#  2   income18  51 non-null     float64
#  3   income19  51 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 1.7+ KB

# %% [markdown]
# *Cleaning poverty data*

# %%
states_poverty.head()
# Out:
#         State  Percentage
# 0     Alabama        14.7
# 1      Alaska        11.8
# 2     Arizona        12.1
# 3    Arkansas        15.0
# 4  California        11.4

# %%
#Change columns name
states_poverty.rename(columns = {'State':'state', 'Percentage':'poverty_pct'}, inplace = True)

#Check for duplicate rows
duplicateRowsDF = states_poverty[states_poverty.duplicated()]
print(duplicateRowsDF)

#Reset index
states_poverty = states_poverty.reset_index(drop = True)

states_poverty.info()
# Out:
# Empty DataFrame
# Columns: [state, poverty_pct]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        51 non-null     object
#  1   poverty_pct  51 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 944.0+ bytes

# %% [markdown]
# *Cleaning GDP data*

# %%
states_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   GeoName      408 non-null    object
#  1   Description  408 non-null    object
#  2   2017         408 non-null    float64
#  3   2018         408 non-null    float64
#  4   2019         408 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 16.1+ KB

# %%
#Filter out required rows
states_gdp = states_gdp[states_gdp['Description'].str.contains('Current-dollar GDP', na=False)]

#Remove Description and Unit column from states_gdp
states_gdp = states_gdp.drop(columns =['Description'])

#Reset and drop index
states_gdp = states_gdp.reset_index(drop = True)

#Rename columns heading
states_gdp.rename(columns = {'GeoName':'state', '2017':'gdp17', '2018':'gdp18', '2019':'gdp19'}, inplace = True)

#Check for duplicate entries
duplicateRowsDF = states_gdp[states_gdp.duplicated()]
print(duplicateRowsDF)

states_gdp.info()
# Out:
# Empty DataFrame
# Columns: [state, gdp17, gdp18, gdp19]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   state   51 non-null     object
#  1   gdp17   51 non-null     float64
#  2   gdp18   51 non-null     float64
#  3   gdp19   51 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 1.7+ KB

# %%
states_pop.head(3)
# Out:
#      state    pop19
# 0  Alabama  4903185
# 1   Alaska   731545
# 2  Arizona  7278717

# %%
states_gdp.head(3)
# Out:
#      state     gdp17     gdp18     gdp19
# 0  Alabama  215085.9  224046.9  231171.8
# 1   Alaska   53089.3   54711.7   54547.1
# 2  Arizona  330416.1  349907.5  369988.2

# %%
merged_1 = pd.merge(states_income, states_gdp, on = 'state')
merged_2 = pd.merge(states_poverty, merged_1, on = 'state')
merged_3 = pd.merge(states_pop, merged_2, on = 'state')
states_data = pd.merge(all_sat_act, merged_3, on = 'state')
states_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        51 non-null     object
#  1   sat17_part   51 non-null     float64
#  2   sat17_ebrw   51 non-null     int64
#  3   sat17_math   51 non-null     int64
#  4   sat17_total  51 non-null     int64
#  5   act17_part   51 non-null     float64
#  6   act17_eng    51 non-null     float64
#  7   act17_math   51 non-null     float64
#  8   act17_read   51 non-null     float64
#  9   act17_sci    51 non-null     float64
#  10  act17_comp   51 non-null     float64
#  11  sat18_part   51 non-null     float64
#  12  sat18_ebrw   51 non-null     int64
#  13  sat18_math   51 non-null     int64
#  14  sat18_total  51 non-null     int64
#  15  act18_part   51 non-null     float64
#  16  act18_comp   51 non-null     float64
#  17  sat19_part   51 non-null     float64
# ...

# %%
states_data.head()
# Out:
#         state  sat17_part  sat17_ebrw  sat17_math  sat17_total  act17_part  \
# 0     Alabama        0.05         593         572         1165        1.00
# 1      Alaska        0.38         547         533         1080        0.65
# 2     Arizona        0.30         563         553         1116        0.62
# 3    Arkansas        0.03         614         594         1208        1.00
# 4  California        0.53         531         524         1055        0.31
#
#    act17_eng  act17_math  act17_read  act17_sci  ...  act19_part  act19_comp  \
# 0       18.9        18.4        19.7       19.4  ...        1.00        18.9
# 1       18.7        19.8        20.4       19.9  ...        0.38        20.1
# 2       18.6        19.8        20.1       19.8  ...        0.73        19.0
# 3       18.9        19.0        19.7       19.5  ...        1.00        19.3
# 4       22.5        22.7        23.1       22.2  ...        0.23        22.6
#
# ...

# %%
states_data['gdp19_percap'] = round((states_data['gdp19'] * 100_0000) / states_data['pop19'])

# %%
states_data.head()
# Out:
#         state  sat17_part  sat17_ebrw  sat17_math  sat17_total  act17_part  \
# 0     Alabama        0.05         593         572         1165        1.00
# 1      Alaska        0.38         547         533         1080        0.65
# 2     Arizona        0.30         563         553         1116        0.62
# 3    Arkansas        0.03         614         594         1208        1.00
# 4  California        0.53         531         524         1055        0.31
#
#    act17_eng  act17_math  act17_read  act17_sci  ...  act19_comp     pop19  \
# 0       18.9        18.4        19.7       19.4  ...        18.9   4903185
# 1       18.7        19.8        20.4       19.9  ...        20.1    731545
# 2       18.6        19.8        20.1       19.8  ...        19.0   7278717
# 3       18.9        19.0        19.7       19.5  ...        19.3   3017804
# 4       22.5        22.7        23.1       22.2  ...        22.6  39512223
#
# ...

# %% [markdown]
# ### 11. Save cleaned and merged dataframes as csv file

# %%
#Save the clean and merged datasets
sat_act_17.to_csv('../data/sat_act_17.csv')
sat_act_18.to_csv('../data/sat_act_18.csv')
sat_act_19.to_csv('../data/sat_act_19.csv')
#sat19_ca.to_csv('../data/cleaned_sat19_ca.csv')
#act19_ca.to_csv('../data/cleaned_act19_ca.csv')

all_sat_act.to_csv('../data/combined_sat_act.csv')

states_data.to_csv('../data/states_data.csv')

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# **Data Dictionary for ACT 2017, SAT 2017**
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|obj|ACT/SAT|State|
# |sat17_part|float64|ACT/SAT|Statewide SAT Participation Rate, 2017|
# |sat17_ebrw|int64|ACT/SAT|State mean score, SAT Reading/Writing (200-800), 2017|
# |sat17_math|int64|ACT/SAT|State mean score, SAT Math (200-800), 2017|
# |sat17_total|int64|ACT/SAT|State mean total SAT score (400-1600), 2017|
# |act17_part|float64|ACT/SAT|Statewide ACT Participation Rate, 2017|
# |act17_eng|float64|ACT/SAT|State mean score, ACT English (1-36), 2017|
# |act17_math|float64|ACT/SAT|State mean score, ACT English (1-36), 2017|
# |act17_read|float64|ACT/SAT|State mean score, ACT Reading (1-36), 2017|
# |act17_sci|float64|ACT/SAT|State mean score, ACT Science (1-36), 2017|
# |act17_comp|float64|ACT/SAT|State mean ACT Composite Score (1-36), 2017|

# %% [markdown]
# **Data Dictionary for ACT 2018, SAT 2018**
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|obj|ACT/SAT|State|
# |sat18_part|float64|ACT/SAT|Statewide SAT Participation Rate, 2018|
# |sat18_ebrw|int64|ACT/SAT|State mean score, SAT Reading/Writing (200-800), 2018|
# |sat18_math|int64|ACT/SAT|State mean score, SAT Math (200-800), 2018|
# |sat18_total|int64|ACT/SAT|State mean total SAT score (400-1600), 2018|
# |act18_part|float64|ACT/SAT|Statewide ACT Participation Rate, 2018|
# |act18_eng|float64|ACT/SAT|State mean score, ACT English (1-36), 2018|
# |act18_math|float64|ACT/SAT|State mean score, ACT English (1-36), 2018|
# |act18_read|float64|ACT/SAT|State mean score, ACT Reading (1-36), 2018|
# |act18_sci|float64|ACT/SAT|State mean score, ACT Science (1-36), 2018|
# |act18_comp|float64|ACT/SAT|State mean ACT Composite Score (1-36), 2018|

# %% [markdown]
# **Data Dictionary for ACT 2019, SAT 2019**
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|obj|ACT/SAT|State|
# |sat19_part|float64|ACT/SAT|Statewide SAT Participation Rate, 2019|
# |sat19_ebrw|int64|ACT/SAT|State mean score, SAT Reading/Writing (200-800), 2019|
# |sat19_math|int64|ACT/SAT|State mean score, SAT Math (200-800), 2019|
# |sat19_total|int64|ACT/SAT|State mean total SAT score (400-1600), 2019|
# |act19_part|float64|ACT/SAT|Statewide ACT Participation Rate, 2019|
# |act19_eng|float64|ACT/SAT|State mean score, ACT English (1-36), 2019|
# |act19_math|float64|ACT/SAT|State mean score, ACT English (1-36), 2019|
# |act19_read|float64|ACT/SAT|State mean score, ACT Reading (1-36), 2019|
# |act19_sci|float64|ACT/SAT|State mean score, ACT Science (1-36), 2019|
# |act19_comp|float64|ACT/SAT|State mean ACT Composite Score (1-36), 2019|

# %% [markdown]
# **Data Dictionary for ACT 2019 California**
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |cds|obj|ACT 2019 CA|County/District/School Code|
# |ccode|float64|ACT 2019 CA|County Code|
# |cname|int64|ACT 2019 CA|County Name|
# |enroll|int64|ACT 2019 CA|Enrollment of Grade 12|
# |num_tst_takr|int64|ACT 2019 CA|Number of Test Takers of Grade 12|
# |avg_scr_read|float64|ACT 2019 CA|State mean score, ACT Reading (1-36), 2019|
# |avg_scr_eng|float64|ACT 2019 CA|State mean score, ACT English (1-36), 2019|
# |avg_scr_math|float64|ACT 2019 CA|State mean score, ACT Math (1-36), 2019|
# |avg_scr_sci|float64|ACT 2019 CA|State mean score, ACT Science (1-36), 2019|
# |num_ge_21|float64|ACT 2019 CA|Number of Test Takers Whose ACT Composite Scores Are Greater or Equal to 21|
# |pct_ge_21|float64|ACT 2019 CA|Percent of Test Takers Whose ACT Composite Scores Are Greater or Equal to 21|
# |year|float64|ACT 2019 CA|Test Administration Academic Year|

# %% [markdown]
# **Data Dictionary for SAT 2019 California**
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |cds|obj|SAT 2019 CA|County/District/School Code|
# |ccode|float64|SAT 2019 CA|County Code|
# |cname|int64|SAT 2019 CA|County Name|
# |enroll|int64|SAT 2019 CA|Enrollment of Grade 12|
# |num_tst_takr|int64|SAT 2019 CA|Number of Test Takers of Grade 12|
# |num_erw_bm|float64|SAT 2019 CA|The number of students who met or exceeded the benchmark for SAT Evidence-Based Reading & Writing (ERW) test|
# |pct_erw_bm|float64|SAT 2019 CA|The percent of students who met or exceeded the benchmark for Evidence-Based Reading & Writing (ERW)|
# |num_math_bm|float64|SAT 2019 CA|The number of students who met or exceeded the benchmark for SAT Math test|
# |pct_math_bm|float64|SAT 2019 CA|The percent of students who met or exceeded the benchmark for SAT Math test|
# |tot_num_both_bm|float64|SAT 2019 CA|The total number of students who met the benchmark of both Evidence-Based Reading & Writing (ERW) and Math|
# |pct_both_bm|float64|SAT 2019 CA|The percent of students who met the benchmark of both Evidence-Based Reading & Writing (ERW) and Math), 2019|
# |year|float64|SAT 2019 CA|Test Administration Academic Year|

# %% [markdown]
# **Data Dictionary for States Data**
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|obj|STATES DATA|State|
# |poverty_pct|float64|STATES DATA|3-year average percentage of people in poverty, 2017-2019|
# |income_2017|float64|STATES DATA|Median household income for 2017|
# |income_2018|float64|STATES DATA|Median household income for 2018|
# |income_2019|float64|STATES DATA|Median household income for 2019|
# |gdp_2017|float64|STATES DATA|Current-dollar GDP for 2017|
# |gdp_2018|float64|STATES DATA|Current-dollar GDP for 2018|
# |gdp_2019|float64|STATES DATA|Current-dollar GDP for 2019|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - a
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### 1. Summary Statistics

# %%
summary = states_data.describe()
summary.transpose()
# Out:
#              count           mean            std       min        25%  \
# sat17_part    51.0       0.398039       0.352766      0.02      0.040
# sat17_ebrw    51.0     569.117647      45.666901    482.00    533.500
# sat17_math    51.0     556.882353      47.121395    468.00    523.500
# sat17_total   51.0    1126.098039      92.494812    950.00   1055.500
# act17_part    51.0       0.652549       0.321408      0.08      0.310
# act17_eng     51.0      20.931373       2.353677     16.30     19.000
# act17_math    51.0      21.182353       1.981989     18.00     19.400
# act17_read    51.0      22.013725       2.067271     18.10     20.450
# act17_sci     51.0      21.041176       3.182463      2.30     19.900
# act17_comp    51.0      21.519608       2.020695     17.80     19.800
# sat18_part    51.0       0.457451       0.373143      0.02      0.045
# sat18_ebrw    51.0     563.686275      47.502627    480.00    534.500
# ...

# %% [markdown]
# ### 2. Use a dictionary comprehension to apply the standard deviation function to each numeric column in the dataframe.

# %%
sd = {'sat17_part': std_dev(combined_sat_act['sat17_part']),
     'sat17_ebrw': std_dev(combined_sat_act['sat17_ebrw']),
     'sat17_math': std_dev(combined_sat_act['sat17_math']),
     'sat17_total': std_dev(combined_sat_act['sat17_total']),
     'act17_part': std_dev(combined_sat_act['act17_part']),
     'act17_eng': std_dev(combined_sat_act['act17_eng']),
     'act17_math': std_dev(combined_sat_act['act17_math']),
     'act17_read': std_dev(combined_sat_act['act17_read']),
     'act17_sci': std_dev(combined_sat_act['act17_sci']),
     'act17_comp': std_dev(combined_sat_act['act17_comp']),
     'sat18_part': std_dev(combined_sat_act['sat18_part']),
     'sat18_ebrw': std_dev(combined_sat_act['sat18_ebrw']),
     'sat18_math': std_dev(combined_sat_act['sat18_math']),
     'sat18_total': std_dev(combined_sat_act['sat18_total']),
     'act18_part': std_dev(combined_sat_act['act18_part']),
     'act18_comp': std_dev(combined_sat_act['act18_comp']),
     'sat19_part': std_dev(combined_sat_act['sat19_part']),
     'sat19_ebrw': std_dev(combined_sat_act['sat19_ebrw']),
     'sat19_math': std_dev(combined_sat_act['sat19_math']),
     'sat19_total': std_dev(combined_sat_act['sat19_total']),
     'act19_part': std_dev(combined_sat_act['act19_part']),
     'act19_comp': std_dev(combined_sat_act['act19_comp'])
     }

sd
# Out:
# {'sat17_part': 0.3492907076664507,
#  'sat17_ebrw': 45.21697020437866,
#  'sat17_math': 46.65713364485503,
#  'sat17_total': 91.58351056778743,
#  'act17_part': 0.3182417575123181,
#  'act17_eng': 2.3304876369363363,
#  'act17_math': 1.9624620273436781,
#  'act17_read': 2.0469029314842646,
#  'act17_sci': 3.151107895464408,
#  'act17_comp': 2.000786081581989,
#  'sat18_part': 0.3694661922353942,
#  'sat18_ebrw': 47.03460978357609,
#  'sat18_math': 47.30194550378352,
#  'sat18_total': 93.22742384464433,
#  'act18_part': 0.33701735820410317,
#  'act18_comp': 2.090779082141178,
#  'sat19_part': 0.3836584048685726,
#  'sat19_ebrw': 45.792378682545134,
#  'sat19_math': 50.78521461840036,
#  'sat19_total': 96.24027185617864,
#  'act19_part': 0.3417582373703047,
#  'act19_comp': 2.172901153595978}

# %% [markdown]
# ### 3. Investigate trends in the dataset

# %% [markdown]
# **How does California state fare for SAT/ ACT against the rest of the states in USA? Crime rate/ household income/ gdp? See if there’s a correlation to the level of participation in SAT & ACT as a whole?**

# %%
#Participation rate for California SAT and ACT 
states_data.loc[(states_data.state == 'California'), ['state','sat17_part','sat18_part','sat19_part']]
# Out:
#         state  sat17_part  sat18_part  sat19_part
# 4  California        0.53         0.6        0.63

# %%
states_data.loc[(states_data.state == 'California'), ['state','act17_part','act18_part','act19_part']]
# Out:
#         state  act17_part  act18_part  act19_part
# 4  California        0.31        0.27        0.23

# %%
states_data['act19_part'].describe()
# Out:
# count    51.000000
# mean      0.586667
# std       0.345159
# min       0.060000
# 25%       0.245000
# 50%       0.540000
# 75%       1.000000
# max       1.000000
# Name: act19_part, dtype: float64

# %%
states_data['sat19_part'].describe()
# Out:
# count    51.000000
# mean      0.490588
# std       0.387476
# min       0.020000
# 25%       0.055000
# 50%       0.540000
# 75%       0.820000
# max       1.000000
# Name: sat19_part, dtype: float64

# %%
#Tests results for California SAT and ACT 
states_data.loc[(states_data.state == 'California'), ['sat17_total','sat18_total','sat19_total','act17_comp','act18_comp','act19_comp']]

# %%
#Average States SAT participation rate for 2017-2019
cols = ['sat17_part','sat18_part','sat19_part']
cols_mean = states_data[cols].mean()
print(cols_mean)
print(cols_mean.sum())
# Out:
# sat17_part    0.398039
# sat18_part    0.457451
# sat19_part    0.490588
# dtype: float64
# 1.346078431372549

# %%
#Average States ACT participation rate for 2017-2019
cols_act = ['act17_part','act18_part','act19_part']
mean_act = states_data[cols_act].mean()
print(mean_act)
print(mean_act.sum())
# Out:
# act17_part    0.652549
# act18_part    0.617255
# act19_part    0.586667
# dtype: float64
# 1.8564705882352939

# %%
states_data.iloc[4]['act19_part']

# %% [markdown]
# *The ACT participation rate for California were quite low as compared to other states.
# The ACT shown a downward trend.*

# %%
states_data['sat17_part'].hist(bins=50)
plt.xlabel("2017 SAT Participation Rate (1.0 = 100%)")
plt.ylabel("Number of States")
plt.ylim([0, 12]);
plt.title('# of States vs. 2017 SAT Participation Rate');

# %%
#States GDP for 2017, 2018 & 2019
states_data[states_data.columns[[0,27,28,29]]].sort_values(['gdp_2017','gdp_2018','gdp_2019'], ascending=False).head(3)
# Out:
#          state   gdp_2017   gdp_2018   gdp_2019
# 4   California  2730973.9  2895101.0  3052645.2
# 43       Texas  1677110.9  1809706.4  1863953.8
# 32    New York  1603903.4  1694957.9  1777751.8

# %% [markdown]
# *The GDP for California as shown above were the highest for 2017 to 2019, and showing an upward trend.*

# %%
#States median household income for 2017, 2018 & 2019
states_data[states_data.columns[[0,24,25,26]]].sort_values(['income_2017','income_2018','income_2019'],\
ascending=False).head(10)
# Out:
#                    state  income_2017  income_2018  income_2019
# 8   District of Columbia      85900.0      86700.0      92300.0
# 20              Maryland      84200.0      84800.0      86700.0
# 30            New Jersey      83500.0      83200.0      85800.0
# 11                Hawaii      81100.0      81700.0      83100.0
# 21         Massachusetts      80700.0      81300.0      85800.0
# 6            Connecticut      77400.0      77700.0      78800.0
# 29         New Hampshire      76500.0      76300.0      77900.0
# 1                 Alaska      76300.0      75700.0      75500.0
# 4             California      74900.0      76600.0      80400.0
# 46              Virginia      74600.0      73900.0      76500.0

# %% [markdown]
# *From above, the median household income for California state was above the 75% quantile, and showing an upward trend.*

# %%
#Quantiles for State's poverty
states_data['poverty_pct'].quantile(q=[0, 0.25, 0.5, 0.75])
# Out:
# 0.00     5.60
# 0.25     9.55
# 0.50    10.60
# 0.75    12.55
# Name: poverty_pct, dtype: float64

# %% [markdown]
# *The percentage of people in poverty for California was quite high at 11.4%, which is above the 50% quantile.*

# %%
#Quantiles for tests result
print(states_data['sat17_total'].quantile(q=[0, 0.25, 0.5, 0.75]))
print(states_data['sat18_total'].quantile(q=[0, 0.25, 0.5, 0.75]))
print(states_data['sat19_total'].quantile(q=[0, 0.25, 0.5, 0.75]))
print(states_data['act17_comp'].quantile(q=[0, 0.25, 0.5, 0.75]))
print(states_data['act18_comp'].quantile(q=[0, 0.25, 0.5, 0.75]))
print(states_data['act19_comp'].quantile(q=[0, 0.25, 0.5, 0.75]))
# Out:
# 0.00     950.0
# 0.25    1055.5
# 0.50    1107.0
# 0.75    1212.0
# Name: sat17_total, dtype: float64
# 0.00     977.0
# 0.25    1057.5
# 0.50    1098.0
# 0.75    1204.0
# Name: sat18_total, dtype: float64
# 0.00     943.0
# 0.25    1038.0
# 0.50    1097.0
# 0.75    1210.0
# Name: sat19_total, dtype: float64
# 0.00    17.8
# 0.25    19.8
# 0.50    21.4
# 0.75    23.6
# Name: act17_comp, dtype: float64
# 0.00    17.70
# 0.25    19.95
# 0.50    21.30
# 0.75    23.65
# Name: act18_comp, dtype: float64
# 0.00    17.9
# 0.25    19.8
# 0.50    21.1
# 0.75    23.7
# Name: act19_comp, dtype: float64

# %%
states_data.head(3)
# Out:
#      state  sat17_part  sat17_ebrw  sat17_math  sat17_total  act17_part  \
# 0  Alabama        0.05         593         572         1165        1.00
# 1   Alaska        0.38         547         533         1080        0.65
# 2  Arizona        0.30         563         553         1116        0.62
#
#    act17_eng  act17_math  act17_read  act17_sci  ...  act19_comp    pop19  \
# 0       18.9        18.4        19.7       19.4  ...        18.9  4903185
# 1       18.7        19.8        20.4       19.9  ...        20.1   731545
# 2       18.6        19.8        20.1       19.8  ...        19.0  7278717
#
#    poverty_pct  income17  income18  income19     gdp17     gdp18     gdp19  \
# 0         14.7   50200.0   50800.0   51700.0  215085.9  224046.9  231171.8
# 1         11.8   76300.0   75700.0   75500.0   53089.3   54711.7   54547.1
# 2         12.1   59000.0   60300.0   62100.0  330416.1  349907.5  369988.2
#
#    gdp19_percap
# 0       47147.0
# 1       74564.0
# 2       50832.0
#
# ...

# %%
#Tests results for California SAT and ACT 
states_data.loc[(states_data.state == 'California'), ['sat17_total','sat18_total','sat19_total','act17_comp','act18_comp','act19_comp']]
# Out:
#    sat17_total  sat18_total  sat19_total  act17_comp  act18_comp  act19_comp
# 4         1055         1076         1065        22.8        22.7        22.6

# %%
states_data.loc[(states_data.state == 'California'), ['state','pop19','poverty_pct','income19','income18','gdp19','gdp19_percap']]
# Out:
#         state     pop19  poverty_pct  income19  income18      gdp19  \
# 4  California  39512223         11.4   80400.0   76600.0  3052645.2
#
#    gdp19_percap
# 4       77258.0

# %%
states_data['income19'].describe()
# Out:
# count       51.000000
# mean     65513.725490
# std      11171.016419
# min      45800.000000
# 25%      57500.000000
# 50%      63200.000000
# 75%      75050.000000
# max      92300.000000
# Name: income19, dtype: float64

# %% [markdown]
# Households in California have a median annual income of $80,400, which is more than the median annual income of $63,200 across the entire United States. This is in comparison to a median income of $76,600 in 2018, which represents a 4.96% annual growth.

# %%
#Poverty vs participation
states_data.sort_values(['income19','poverty_pct','act19_part','sat19_part'], \
ascending=False).head(10).loc[:,['state','income19','poverty_pct','act19_part','sat19_part']]
# Out:
#                    state  income19  poverty_pct  act19_part  sat19_part
# 8   District of Columbia   92300.0         13.7        0.32        0.94
# 20              Maryland   86700.0          7.5        0.28        0.82
# 21         Massachusetts   85800.0          9.2        0.21        0.81
# 30            New Jersey   85800.0          8.2        0.25        0.82
# 11                Hawaii   83100.0          9.4        0.80        0.54
# 4             California   80400.0         11.4        0.23        0.63
# 6            Connecticut   78800.0          9.7        0.22        1.00
# 47            Washington   78700.0          8.8        0.24        0.70
# 29         New Hampshire   77900.0          5.6        0.14        0.95
# 5               Colorado   77100.0          9.1        0.27        1.00

# %%
states_data.sort_values(['poverty_pct','income19','act19_part','sat19_part'], \
ascending=False).head(10).loc[:,['state','poverty_pct','income19','act19_part','sat19_part']]
# Out:
#                    state  poverty_pct  income19  act19_part  sat19_part
# 18             Louisiana         19.1   51100.0        1.00        0.05
# 24           Mississippi         19.1   45800.0        1.00        0.03
# 31            New Mexico         17.2   51900.0        0.63        0.18
# 48         West Virginia         15.6   48900.0        0.49        0.99
# 3               Arkansas         15.0   49000.0        1.00        0.06
# 0                Alabama         14.7   51700.0        1.00        0.07
# 40        South Carolina         14.4   56200.0        0.78        0.68
# 17              Kentucky         14.2   52300.0        1.00        0.04
# 8   District of Columbia         13.7   92300.0        0.32        0.94
# 33        North Carolina         13.6   57300.0        1.00        0.51

# %%
states_data['poverty_pct'].describe()
# Out:
# count    51.000000
# mean     11.272549
# std       2.828008
# min       5.600000
# 25%       9.550000
# 50%      10.600000
# 75%      12.550000
# max      19.100000
# Name: poverty_pct, dtype: float64

# %% [markdown]
# *ACT performance scored better than SAT.*

# %%
#ACT participation rate for 2017
alt.Chart(states_data).mark_bar().encode(
    x=alt.X('state', title='State'),
    y=alt.Y('act17_part', title='Participation Rates (%)'),
    color=alt.condition(
        alt.datum.state == 'California',
        alt.value('red'),
        alt.value('grey')
    )
).properties(width=500, title='ACT Participation Rates for 2017')
# Out:
# alt.Chart(...)

# %%
#ACT participation rate for 2018
alt.Chart(states_data).mark_bar().encode(
    x=alt.X('state', title='State'),
    y=alt.Y('act18_part', title='Participation Rates (%)'),
    color=alt.condition(
        alt.datum.state == 'California',
        alt.value('red'),
        alt.value('grey')
    )
).properties(width=500, title='ACT Participation Rates for 2018')
# Out:
# alt.Chart(...)

# %%
#ACT participation rate for 2019
alt.Chart(states_data).mark_bar().encode(
    x=alt.X('state', title='State'),
    y=alt.Y('act19_part', title='Participation Rates (%)'),
    color=alt.condition(
        alt.datum.state == 'California',
        alt.value('red'),
        alt.value('grey')
    )
).properties(width=500, title='ACT Participation Rates for 2019')
# Out:
# alt.Chart(...)

# %%
#SAT participation rate for 2017
alt.Chart(states_data).mark_bar().encode(
    x=alt.X('state', title='State'),
    y=alt.Y('sat17_part', title='Participation Rates (%)'),
    color=alt.condition(
        alt.datum.state == 'California',
        alt.value('blue'),
        alt.value('grey')
    )
).properties(width=500, title='SAT Participation Rates for 2017')
# Out:
# alt.Chart(...)

# %%
#SAT participation rate for 2018
alt.Chart(states_data).mark_bar().encode(
    x=alt.X('state', title='State'),
    y=alt.Y('sat18_part', title='Participation Rates (%)'),
    color=alt.condition(
        alt.datum.state == 'California',
        alt.value('blue'),
        alt.value('grey')
    )
).properties(width=500, title='SAT Participation Rates for 2018')
# Out:
# alt.Chart(...)

# %%
#SAT participation rate for 2019
alt.Chart(states_data).mark_bar().encode(
    x=alt.X('state', title='State'),
    y=alt.Y('sat19_part', title='Participation Rates (%)'),
    color=alt.condition(
        alt.datum.state == 'California',
        alt.value('blue'),
        alt.value('grey')
    )
).properties(width=500, title='SAT Participation Rates for 2019')
# Out:
# alt.Chart(...)

# %%
# plot a histogram for states GDP
f, ax = plt.subplots(figsize=(20,6))
gdp_states = sns.barplot(x='state',y='gdp_2017',data=states_gdp)
gdp_states.set_xticklabels(states_gdp['state'],rotation=90);
plt.title('States GDP');

# %% [markdown]
# **Which county have the highest enrollment for SAT and ACT in 2019? what is the average.**

# %% [markdown]
# For SAT

# %%
sat19_ca.sort_values(['enroll'], ascending=False).head()
# Out:
#              cds  ccode           cname    enroll  num_tst_takr  num_erw_bm  \
# 1   1.900000e+13   19.0     Los Angeles  114618.0       48676.0     30081.0
# 35  3.700000e+13   37.0       San Diego   42040.0       12872.0     10086.0
# 15  3.000000e+13   30.0          Orange   41235.0       16061.0     11463.0
# 54  3.300000e+13   33.0       Riverside   34277.0       14070.0      8572.0
# 9   3.600000e+13   36.0  San Bernardino   31635.0       10544.0      7014.0
#
#     pct_erw_bm  num_math_bm  pct_math_bm  tot_num_both_bm  pct_both_bm  year
# 1        61.80      19791.0        40.66          18555.0        38.12  2019
# 35       78.36       7462.0        57.97           7146.0        55.52  2019
# 15       71.37       8971.0        55.86           8533.0        53.13  2019
# 54       60.92       5121.0        36.40           4799.0        34.11  2019
# 9        66.52       4368.0        41.43           4083.0        38.72  2019

# %%
sat19_ca['enroll'].mean()
# Out:
# 8442.241379310344

# %% [markdown]
# For ACT

# %%
act19_ca.sort_values(['enroll'], ascending=False).head()
# Out:
#              cds  ccode           cname    enroll  num_tst_takr  avg_scr_read  \
# 57  1.900000e+13   19.0     Los Angeles  114618.0       20678.0          21.0
# 28  3.700000e+13   37.0       San Diego   42040.0        8081.0          24.0
# 25  3.000000e+13   30.0          Orange   41235.0        8501.0          25.0
# 29  3.300000e+13   33.0       Riverside   34277.0        4767.0          21.0
# 37  3.600000e+13   36.0  San Bernardino   31635.0        5418.0          18.0
#
#     avg_scr_eng  avg_scr_math  avg_scr_sci  num_ge_21  pct_ge_21  year
# 57         20.0          21.0         20.0     9182.0      44.40  2019
# 28         23.0          23.0         23.0     5231.0      64.73  2019
# 25         24.0          24.0         24.0     6087.0      71.60  2019
# 29         20.0          20.0         20.0     2144.0      44.98  2019
# 37         17.0          19.0         18.0     1550.0      28.61  2019

# %%
round(act19_ca['enroll'].mean(),2)
# Out:
# 8442.24

# %% [markdown]
# **Which county have the highest and lowest participation rates for SAT and ACT in 2019? what is the average?**

# %% [markdown]
# For SAT

# %%
#Create a new column for participation rates for SAT 2019
sat19_ca['part_rate'] = sat19_ca['num_tst_takr'] / sat19_ca['enroll']

# %%
#Show highest participation rate for SAT 2019 CA
sat19_ca.sort_values(['part_rate'], ascending=False).head()
# Out:
#              cds  ccode          cname    enroll  num_tst_takr  num_erw_bm  \
# 57  3.800000e+13   38.0  San Francisco    4447.0        2256.0      1579.0
# 17  4.100000e+13   41.0      San Mateo    7235.0        3113.0      2410.0
# 1   1.900000e+13   19.0    Los Angeles  114618.0       48676.0     30081.0
# 51  5.600000e+13   56.0        Ventura   10750.0        4534.0      2815.0
# 54  3.300000e+13   33.0      Riverside   34277.0       14070.0      8572.0
#
#     pct_erw_bm  num_math_bm  pct_math_bm  tot_num_both_bm  pct_both_bm  year  \
# 57       69.99       1380.0        61.17           1248.0        55.32  2019
# 17       77.42       1945.0        62.48           1857.0        59.65  2019
# 1        61.80      19791.0        40.66          18555.0        38.12  2019
# 51       62.09       2068.0        45.61           1967.0        43.38  2019
# 54       60.92       5121.0        36.40           4799.0        34.11  2019
#
#     part_rate
# 57   0.507308
# 17   0.430270
# ...

# %%
#Show lowest participation rate SAT 2019 CA
sat19_ca.sort_values(by='part_rate', ascending=True).head()
# Out:
#              cds  ccode     cname  enroll  num_tst_takr  num_erw_bm  \
# 37  5.300000e+13   53.0   Trinity   154.0          13.0         NaN
# 34  2.600000e+13   26.0      Mono   420.0          37.0        32.0
# 29  2.900000e+13   29.0    Nevada  1869.0         186.0       159.0
# 36  5.200000e+13   52.0    Tehama   688.0          91.0        69.0
# 13  5.500000e+13   55.0  Tuolumne   518.0          80.0        66.0
#
#     pct_erw_bm  num_math_bm  pct_math_bm  tot_num_both_bm  pct_both_bm  year  \
# 37         NaN          NaN          NaN              NaN          NaN  2019
# 34       86.49         21.0        56.76             21.0        56.76  2019
# 29       85.48        131.0        70.43            127.0        68.28  2019
# 36       75.82         53.0        58.24             52.0        57.14  2019
# 13       82.50         48.0        60.00             48.0        60.00  2019
#
#     part_rate
# 37   0.084416
# 34   0.088095
# 29   0.099518
# 36   0.132267
# 13   0.154440

# %%
#Show the average participation rate
round(sat19_ca['part_rate'].mean(), 2)
# Out:
# 0.26

# %% [markdown]
# For ACT

# %%
#Create a new column for participation rates for ACT 2019
act19_ca['part_rate'] = act19_ca['num_tst_takr'] / act19_ca['enroll']

# %%
#Show highest participation rate
act19_ca.sort_values(['part_rate'], ascending=False).head()
# Out:
#              cds  ccode          cname   enroll  num_tst_takr  avg_scr_read  \
# 30  2.500000e+13   25.0          Modoc     87.0          55.0          17.0
# 46  5.200000e+13   52.0         Tehama    688.0         302.0          19.0
# 8   2.100000e+13   21.0          Marin   2647.0         753.0          27.0
# 54  3.800000e+13   38.0  San Francisco   4447.0        1078.0          22.0
# 26  7.000000e+12    7.0   Contra Costa  14593.0        3183.0          25.0
#
#     avg_scr_eng  avg_scr_math  avg_scr_sci  num_ge_21  pct_ge_21  year  \
# 30         15.0          17.0         18.0       11.0      20.00  2019
# 46         18.0          19.0         19.0      105.0      34.77  2019
# 8          26.0          25.0         25.0      606.0      80.48  2019
# 54         21.0          22.0         21.0      565.0      52.41  2019
# 26         25.0          24.0         24.0     2250.0      70.69  2019
#
#     part_rate
# 30   0.632184
# 46   0.438953
# 8    0.284473
# 54   0.242411
# ...

# %%
#Show lowest participation rate
act19_ca.sort_values(by='part_rate', ascending=True).head()
# Out:
#              cds  ccode      cname  enroll  num_tst_takr  avg_scr_read  \
# 41  8.000000e+12    8.0  Del Norte   363.0           5.0           NaN
# 56  2.900000e+13   29.0     Nevada  1869.0          76.0          25.0
# 31  5.500000e+13   55.0   Tuolumne   518.0          23.0          26.0
# 6   2.600000e+13   26.0       Mono   420.0          20.0          26.0
# 18  1.400000e+13   14.0       Inyo   548.0          28.0          23.0
#
#     avg_scr_eng  avg_scr_math  avg_scr_sci  num_ge_21  pct_ge_21  year  \
# 41          NaN           NaN          NaN        NaN        NaN  2019
# 56         24.0          24.0         24.0       57.0      75.00  2019
# 31         23.0          23.0         23.0       18.0      78.26  2019
# 6          24.0          24.0         24.0       16.0      80.00  2019
# 18         22.0          22.0         22.0       19.0      67.86  2019
#
#     part_rate
# 41   0.013774
# 56   0.040663
# 31   0.044402
# 6    0.047619
# 18   0.051095

# %%
#Show the average participation rate
round(act19_ca['part_rate'].mean(), 2)
# Out:
# 0.15

# %% [markdown]
# **Do any county show have >50% participation on both tests in 2019?**

# %%
sat19_ca[sat19_ca.columns[[2,12]]][(sat19_ca['part_rate']>0.5)]
# Out:
#             cname  part_rate
# 57  San Francisco   0.507308

# %%
act19_ca[act19_ca.columns[[2,12]]][(act19_ca['part_rate']>0.5)]
# Out:
#     cname  part_rate
# 30  Modoc   0.632184

# %% [markdown]
# Ans: None

# %% [markdown]
# **a) Which states have the highest and lowest participation rates for the 2017, 2018, or 2019 SAT and ACT?**

# %% [markdown]
# Highest Participation Rates for SAT

# %%
states_data.sort_values(['sat17_part','sat17_total','sat18_part','sat18_total','sat19_part','sat19_total'], \
ascending=False).head(10).loc[:,['state','sat17_part','sat17_total','sat18_part','sat18_total','sat19_part','sat19_total']]
# Out:
#                    state  sat17_part  sat17_total  sat18_part  sat18_total  \
# 6            Connecticut        1.00         1041        1.00         1053
# 22              Michigan        1.00         1005        1.00         1011
# 7               Delaware        1.00          996        1.00          998
# 8   District of Columbia        1.00          950        0.92          977
# 29         New Hampshire        0.96         1052        0.96         1063
# 19                 Maine        0.95         1012        0.99         1013
# 12                 Idaho        0.93         1005        1.00         1001
# 9                Florida        0.83         1017        0.56         1099
# 21         Massachusetts        0.76         1107        0.80         1125
# 39          Rhode Island        0.71         1062        0.97         1018
#
#     sat19_part  sat19_total
# 6         1.00         1046
# 22        1.00         1003
# 7         1.00          985
# ...

# %% [markdown]
# Lowest Participation Rates for SAT

# %%
states_data.sort_values(['sat17_part','sat17_total','sat18_part','sat18_total','sat19_part','sat19_total'], \
ascending=True).head(10).loc[:,['state','sat17_part','sat17_total','sat18_part','sat18_total','sat19_part','sat19_total']]
# Out:
#            state  sat17_part  sat17_total  sat18_part  sat18_total  \
# 24   Mississippi        0.02         1242        0.03         1236
# 34  North Dakota        0.02         1256        0.02         1283
# 15          Iowa        0.02         1275        0.03         1265
# 3       Arkansas        0.03         1208        0.05         1169
# 41  South Dakota        0.03         1216        0.03         1240
# 50       Wyoming        0.03         1230        0.03         1257
# 44          Utah        0.03         1238        0.04         1010
# 27      Nebraska        0.03         1253        0.03         1252
# 25      Missouri        0.03         1271        0.04         1262
# 49     Wisconsin        0.03         1291        0.03         1294
#
#     sat19_part  sat19_total
# 24        0.03         1237
# 34        0.02         1263
# 15        0.03         1244
# 3         0.06         1141
# 41        0.03         1268
# 50        0.03         1238
# ...

# %% [markdown]
# Highest Participation Rates for ACT

# %%
states_data.sort_values(['act17_part','act17_comp','act18_part','act18_comp','act19_part','act19_comp'], \
ascending=False).head(10).loc[:,['state','act17_part','act17_comp','act18_part','act18_comp','act19_part','act19_comp']]
# Out:
#         state  act17_part  act17_comp  act18_part  act18_comp  act19_part  \
# 23  Minnesota         1.0        21.5        0.99        21.3        0.95
# 5    Colorado         1.0        20.8        0.30        23.9        0.27
# 49  Wisconsin         1.0        20.5        1.00        20.5        1.00
# 25   Missouri         1.0        20.4        1.00        20.0        0.82
# 44       Utah         1.0        20.3        1.00        20.4        1.00
# 26    Montana         1.0        20.3        1.00        20.0        1.00
# 50    Wyoming         1.0        20.2        1.00        20.0        1.00
# 17   Kentucky         1.0        20.0        1.00        20.2        1.00
# 42  Tennessee         1.0        19.8        1.00        19.6        1.00
# 18  Louisiana         1.0        19.5        1.00        19.2        1.00
#
#     act19_comp
# 23        21.4
# 5         23.8
# 49        20.3
# 25        20.8
# 44        20.3
# 26        19.8
# 50        19.8
# 17        19.8
# ...

# %% [markdown]
# **b) Which states have the highest and lowest mean total/composite scores for the 2017, 2018, or 2019 SAT and ACT?**

# %% [markdown]
# Highest Total Scores for SAT

# %%
states_data.sort_values(['sat17_total','sat18_total','sat19_total'], \
ascending=False).head().loc[:,['state','sat17_total','sat18_total','sat19_total']]
# Out:
#         state  sat17_total  sat18_total  sat19_total
# 23  Minnesota         1295         1298         1284
# 49  Wisconsin         1291         1294         1283
# 15       Iowa         1275         1265         1244
# 25   Missouri         1271         1262         1236
# 16     Kansas         1260         1265         1241

# %% [markdown]
# Lowest Total Scores for SAT

# %%
states_data.sort_values(['sat17_total','sat18_total','sat19_total'], \
ascending=True).head().loc[:,['state','sat17_total','sat18_total','sat19_total']]
# Out:
#                    state  sat17_total  sat18_total  sat19_total
# 8   District of Columbia          950          977          975
# 7               Delaware          996          998          985
# 12                 Idaho         1005         1001          993
# 22              Michigan         1005         1011         1003
# 19                 Maine         1012         1013         1013

# %% [markdown]
# Highest Composite Scores for ACT

# %%
states_data.sort_values(['act17_comp','act18_comp','act19_comp'], \
ascending=False).head().loc[:,['state','act17_comp','act18_comp','act19_comp']]
# Out:
#             state  act17_comp  act18_comp  act19_comp
# 29  New Hampshire        25.5        25.1        25.0
# 21  Massachusetts        25.4        25.5        25.5
# 6     Connecticut        25.2        25.6        25.5
# 19          Maine        24.3        24.0        24.3
# 32       New York        24.2        24.5        24.5

# %% [markdown]
# Lowest Composite Scores for ACT

# %%
states_data.sort_values(['act17_comp','act18_comp','act19_comp'], \
ascending=True).head().loc[:,['state','act17_comp','act18_comp','act19_comp']]
# Out:
#              state  act17_comp  act18_comp  act19_comp
# 28          Nevada        17.8        17.7        17.9
# 24     Mississippi        18.6        18.6        18.4
# 40  South Carolina        18.7        18.3        18.8
# 11          Hawaii        19.0        18.9        19.0
# 33  North Carolina        19.1        19.1        19.0

# %%
states_data.sort_values(['gdp_2017','gdp_2018','gdp_2019'], \
ascending=False).head().loc[:,['state','gdp_2017','gdp_2018','gdp_2019']]
# Out:
#          state   gdp_2017   gdp_2018   gdp_2019
# 4   California  2730973.9  2895101.0  3052645.2
# 43       Texas  1677110.9  1809706.4  1863953.8
# 32    New York  1603903.4  1694957.9  1777751.8
# 9      Florida  1002568.1  1057862.3  1116435.4
# 13    Illinois   827075.2   867535.5   890486.1

# %% [markdown]
# **c) Do any states with 100% participation on a given test have a rate change year-to-year?**

# %% [markdown]
# **d) Do any states show have >50% participation on *both* tests each year?**

# %% [markdown]
# **e) Which colleges have the highest median SAT and ACT scores for admittance?**

# %% [markdown]
# **f) Which California school districts have the highest and lowest mean test scores?**

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# Bar chart for ACT participation rate, 2017
alt.Chart(states_data).mark_bar().encode(
    x=alt.X('state', title='State'),
    y=alt.Y('act17_part', title='Participation Rates (%)'),
    color=alt.condition(
        alt.datum.state == 'California',
        alt.value('red'),
        alt.value('grey')
    )
).properties(width=500, title='ACT Participation Rates for 2017')

# %%
# Bar chart for ACT participation rate, 2018
alt.Chart(states_data).mark_bar().encode(
    x=alt.X('state', title='State'),
    y=alt.Y('act18_part', title='Participation Rates (%)'),
    color=alt.condition(
        alt.datum.state == 'California',
        alt.value('red'),
        alt.value('grey')
    )
).properties(width=500, title='ACT Participation Rates for 2018')

# %%
# Bar chart for ACT participation rate, 2019
alt.Chart(states_data).mark_bar().encode(
    x=alt.X('state', title='State'),
    y=alt.Y('act19_part', title='Participation Rates (%)'),
    color=alt.condition(
        alt.datum.state == 'California',
        alt.value('red'),
        alt.value('grey')
    )
).properties(width=500, title='ACT Participation Rates for 2019')

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels, sharex=False, kde=False, figsize=(10,5)):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=figsize, sharex=sharex, sharey=True)
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    
    for i, column in enumerate(list_of_columns):
        # Calculate mean
        mean = np.mean(dataframe[list_of_columns[i]])
        ax[i].axvline(mean, ls='--', color='crimson')

        sns.histplot(data=dataframe, x=column, color='skyblue', ax=ax[i], kde=kde, bins=8)
        ax[i].set_title(list_of_titles[i] + f' (Mean: {mean:.1f})')
        ax[i].set_xlabel(list_of_xlabels[i])
        # To prevent label duplication
        if i % 2 == 0:
            ax[i].set_ylabel('Number of States')
    
    fig.tight_layout(h_pad = 1.5, w_pad = 1.5)

# %%
subplot_histograms(states_data, ['act17_part','sat17_part','act18_part','sat18_part','act19_part','sat19_part'],\
                   ['ACT 2017 Participation','SAT 2017 Participation','ACT 2018 Participation','SAT 2018 Participation',\
                   'ACT 2019 Participation','SAT 2019 Participation'], ['Participation (%)','Participation (%)',\
                    'Participation (%)','Participation (%)','Participation (%)','Participation (%)'], sharex=True, kde=True)

# %% [markdown]
# Overall, we can see that the ACT has a larger baseline following than the SAT. The SAT has a large number of states with an extremely low participation rate, while the ACT has a large number of states with a extremely high participation rate.
#
# From 2017 to 2019, SAT participation has been increasing, while ACT participation has been decreasing on average. This suggests that some states are beginning to adopt the SAT test over the ACT test. The number of states with a 90% - 100% participation for the SAT increased in 2019, while ACT participation rates for states in the same range decreased.

# %%
states_data['sat19_part'].mean()
# Out:
# 0.49058823529411755

# %%
states_data['sat18_part'].mean()
# Out:
# 0.45745098039215676

# %%
states_data['sat17_part'].mean()
# Out:
# 0.39803921568627454

# %%
# Function for plotting scatter plot
def plot_scatter(df, x, y, x_label, y_label, title):
    fig, ax = plt.subplots(figsize=(10,5))
    plt.title(title)
    sns.regplot(data=df, x=x, y=y)
    plt.tight_layout()
    plt.xlabel(x_label)
    plt.ylabel(y_label)

# %% [markdown]
# States Participation rates vs Population size

# %%
#Plot ACT Participation vs Population
plot_scatter(states_data, 'pop19', 'act19_part', 'Population', 'ACT Participation (%)', 'ACT Participation Rates vs Population')
df = states_data.query("state == 'California'")
plt.scatter(df.pop19, df.act19_part, color="red");

# %% [markdown]
# A higher percentage of students nationwide took the test, though the national participation rate also has been in decline.

# %%
#Plot SAT Participation vs Population
plot_scatter(states_data, 'pop19', 'sat19_part', 'Population',  'SAT Participation (%)', 'SAT Participation Rates vs Population')
df = states_data.query("state == 'California'")
plt.scatter(df.pop19, df.sat19_part, color="red");

# %%
#Plot ACT Participation vs GDP per capita
plot_scatter(states_data, 'gdp19_percap', 'act19_part', 'GDP per capita', 'ACT Participation (%)', 'ACT Participation rates vs GDP per capita')
df = states_data.query("state == 'California'")
plt.scatter(df.gdp19_percap, df.act19_part, color="red");

# %%
#Plot SAT Participation vs GDP per capita
plot_scatter(states_data, 'gdp19_percap', 'sat19_part', 'GDP per capita', 'SAT Participation (%)', 'SAT Participation rates vs GDP per capita')
df = states_data.query("state == 'California'")
plt.scatter(df.gdp19_percap, df.sat19_part, color="red");

# %%
#Plot ACT Participation vs Househole income
plot_scatter(states_data, 'income19', 'act19_part', 'Household income', 'ACT Participation (%)', 'ACT Participation rates vs Household income')
df = states_data.query("state == 'California'")
plt.scatter(df.income19, df.act19_part, color="red");

# %%
#Plot SAT Participation vs Househole income
plot_scatter(states_data, 'income19', 'sat19_part', 'Household income', 'SAT Participation (%)', 'SAT Participation rates vs Household income')
df = states_data.query("state == 'California'")
plt.scatter(df.income19, df.sat19_part, color="red");

# %% [markdown]
# Analysis of incomes and test participation show a moderate positive correlation between SAT participation and the household income. Since SAT and ACT participation rates are negatively correlated, this results in a negative correlation between ACT participation and income. Participation rates displayed little correlation with state population.
#
# From the data, we observe that states with a relatively low household income tend to have higher ACT participation rate on average. The opposite is true for states with a relatively low GDP per Captia that take the SAT. This could make a compelling argument for states that are looking to improve their position on the National Assessment of Educational Progress (NAEP).

# %%
#Plot ACT Participation vs Poverty
plot_scatter(states_data, 'poverty_pct', 'act19_part', 'Poverty', 'ACT Participation (%)', 'ACT Participation rates vs Poverty')
df = states_data.query("state == 'California'")
plt.scatter(df.poverty_pct, df.act19_part, color="red");

# %%
#Plot SAT Participation vs Poverty
plot_scatter(states_data, 'poverty_pct', 'sat19_part', 'Poverty', 'SAT Participation (%)', 'SAT Participation rates vs Poverty')
df = states_data.query("state == 'California'")
plt.scatter(df.poverty_pct, df.sat19_part, color="red");

# %%
states_data.sort_values(['gdp19_percap'], ascending=False).head()
# Out:
#                    state  sat17_part  sat17_ebrw  sat17_math  sat17_total  \
# 8   District of Columbia        1.00         482         468          950
# 32              New York        0.67         528         523         1052
# 21         Massachusetts        0.76         555         551         1107
# 6            Connecticut        1.00         530         512         1041
# 7               Delaware        1.00         503         492          996
#
#     act17_part  act17_eng  act17_math  act17_read  act17_sci  ...  act19_comp  \
# 8         0.32       24.4        23.5        24.9       23.5  ...        23.5
# 32        0.31       23.8        24.0        24.6       23.9  ...        24.5
# 21        0.29       25.4        25.3        25.9       24.7  ...        25.5
# 6         0.31       25.5        24.6        25.6       24.6  ...        25.5
# 7         0.18       24.1        23.4        24.8       23.6  ...        24.1
#
# ...

# %%
fig, ax = plt.subplots(figsize=(13,7))
title = "Correlation of states GDP, income and poverty"
sns.heatmap(merged_states_info.corr(), annot = True, cmap = 'coolwarm');

# %%
plt.figure(figsize=(15, 15))
plt.title('Correlation of all data from SAT and ACT 2017-19', size=16)
sns.heatmap(states_data.corr(), annot = True, cmap = 'coolwarm');

# %%
#df_2017 = states_data.groupby('state')['sat17_part']

# %%
ind = np.arange(len(states_data))
width = 0.3

fig, ax = plt.subplots(figsize=(8, 16))
ax.barh(ind + width + width, states_data.sat17_part, width, color='grey', label='2017')
ax.barh(ind + width, states_data.sat18_part, width, color='orange', label='2018')
ax.barh(ind, states_data.sat19_part, width, color='violet', label='2019')

ax.set(yticks=ind + width, yticklabels=states_data.state, ylim=[2*width - 1, len(states_data)])
#ax.set(xticks=ind + width, xticklabels=states_data.state, xlim=[2*width - 1, len(states_data)])
ax.legend()

plt.show()

# %%
#Pairplots for correlation
#sns.pairplot(states_data, kind='reg')

# %%
# Function to plot multiple scatter plots
def multi_plot_scatter(df, list_of_x, list_of_y, list_of_titles, xlabels, ylabels, sharex = False, sharey = False):
    if len(list_of_x) == 1:
        ncols = 1
    else:
        ncols = 2
    nrows = int(np.ceil(len(list_of_x)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(10,8), sharex = sharex, sharey = sharey)
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    
    for i, column in enumerate(list_of_x):
        sns_fig = sns.regplot(data=df, x=list_of_x[i], y=list_of_y[i], ax=ax[i]).set_title(list_of_titles[i])
        ax[i].set_xlabel(xlabels[i])
        ax[i].set_ylabel(ylabels[i])
        plt.tight_layout()

# %%
x_axis_scatter = ['sat17_part','act17_part','sat18_part','act18_part','sat19_part','act19_part']
y_axis_scatter = ['gdp_2017','gdp_2017','gdp_2018','gdp_2018','gdp_2019','gdp_2019']
scatter_titles = ['SAT Participation Rate vs GDP in 2017','ACT Participation Rate vs GDP in 2017',\
                  'SAT Participation Rate vs GDP in 2018','ACT Participation Rate vs GDP in 2018',\
                  'SAT Participation Rate vs GDP in 2019','ACT Participation Rate vs GDP in 2019']
x_axis_labels = ['Participation Rate (in percentage)','Participation Rate (in percentage)',\
                 'Participation Rate (in percentage)','Participation Rate (in percentage)',\
                 'Participation Rate (in percentage)','Participation Rate (in percentage)']
y_axis_labels = ['GDP (in trillions)','GDP (in trillions)','GDP (in trillions)','GDP (in trillions)',\
                 'GDP (in trillions)','GDP (in trillions)']

# %%
# ACT & SAT Correlation for All Data
multi_plot_scatter(states_data, x_axis_scatter, y_axis_scatter, scatter_titles, x_axis_labels, y_axis_labels, sharex = True, sharey = True)

# %%
# A function to create a subplot of scatterplots 

def subplot_scatter(dataframe, list_of_columns1, list_of_columns2, list_of_titles, ylabel, xlabel, figtitle):
    nrows = int(np.ceil(len(list_of_columns1)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(10, 10))  
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate  
    
    for i, (column1, column2) in enumerate(zip(x_axis_scatter, y_axis_scatter)):
        ax[i].scatter(dataframe[column1], dataframe[column2]) 
        ax[i].set_xlabel(xlabel[i])
        ax[i].set_ylabel(ylabel[i])
    for i, title in enumerate(list_of_titles):
        ax[i].set_title(title, fontsize=12)
    fig.suptitle(figtitle, size=16) 
    plt.tight_layout()
    fig.subplots_adjust(top=.93)

# %%
x_axis_scatter = ['sat17_part','act17_part','sat18_part','act18_part','sat19_part','act19_part']
y_axis_scatter = ['gdp_2017','gdp_2017','gdp_2018','gdp_2018','gdp_2019','gdp_2019']
scatter_titles = ['SAT Participation Rate vs GDP in 2017','ACT Participation Rate vs GDP in 2017',\
                  'SAT Participation Rate vs GDP in 2018','ACT Participation Rate vs GDP in 2018',\
                  'SAT Participation Rate vs GDP in 2019','ACT Participation Rate vs GDP in 2019']
x_axis_labels = ['Participation Rate (in percentage)','Participation Rate (in percentage)',\
                 'Participation Rate (in percentage)','Participation Rate (in percentage)',\
                 'Participation Rate (in percentage)','Participation Rate (in percentage)']
y_axis_labels = ['GDP (in trillions)','GDP (in trillions)','GDP (in trillions)','GDP (in trillions)',\
                 'GDP (in trillions)','GDP (in trillions)']

# %%
# ACT & SAT Correlation for All Data
subplot_scatter(states_data, x_axis_scatter, y_axis_scatter, scatter_titles, y_axis_labels, x_axis_labels, 'SAT & ACT Participation Rate vs GDP')

# %%
x_axis_scatter = ['sat17_part','act17_part','sat18_part','act18_part','sat19_part','act19_part']
y_axis_scatter = ['income_2017','income_2017','income_2018','income_2018','income_2019','income_2019']
scatter_titles = ['SAT Participation Rate vs Income in 2017','ACT Participation Rate vs Income in 2017',\
                  'SAT Participation Rate vs Income in 2018','ACT Participation Rate vs Income in 2018',\
                  'SAT Participation Rate vs Income in 2019','ACT Participation Rate vs Income in 2019']
x_axis_labels = ['Participation Rate (in percentage)','Participation Rate (in percentage)',\
                 'Participation Rate (in percentage)','Participation Rate (in percentage)',\
                 'Participation Rate (in percentage)','Participation Rate (in percentage)']
y_axis_labels = ['Income (in dollars)','Income (in dollars)','Income (in dollars)','Income (in dollars)',\
                 'Income (in dollars)','Income (in dollars)']

# %%
# ACT & SAT Correlation for All Data
subplot_scatter(states_data, x_axis_scatter, y_axis_scatter, scatter_titles, y_axis_labels, x_axis_labels, 'SAT & ACT Participation Rate vs Income')

# %%
x_axis_scatter = ['sat17_part','act17_part','sat18_part','act18_part','sat19_part','act19_part']
y_axis_scatter = ['poverty_pct','poverty_pct','poverty_pct','poverty_pct','poverty_pct','poverty_pct']
scatter_titles = ['SAT Participation Rate vs Poverty in 2017','ACT Participation Rate vs Poverty in 2017',\
                  'SAT Participation Rate vs Poverty in 2018','ACT Participation Rate vs Poverty in 2018',\
                  'SAT Participation Rate vs Poverty in 2019','ACT Participation Rate vs Poverty in 2019']
x_axis_labels = ['Participation Rate (in percentage)','Participation Rate (in percentage)',\
                 'Participation Rate (in percentage)','Participation Rate (in percentage)',\
                 'Participation Rate (in percentage)','Participation Rate (in percentage)']
y_axis_labels = ['Poverty (in %, 3-yr avg)','Poverty (in %, 3-yr avg)','Poverty (in %, 3-yr avg)',\
                 'Poverty (in %, 3-yr avg)','Poverty (in %, 3-yr avg)','Poverty (in %, 3-yr avg)']

# %%
# ACT & SAT Correlation for All Data
subplot_scatter(states_data, x_axis_scatter, y_axis_scatter, scatter_titles, y_axis_labels, x_axis_labels, 'SAT & ACT Participation Rate vs Poverty')

# %%
x_axis_scatter = ['sat17_part','act17_part','sat18_part','act18_part','sat19_part','act19_part']
y_axis_scatter = ['sat17_total','act17_comp','sat18_total','act18_comp','sat19_total','act19_comp']
scatter_titles = ['SAT Participation Rate vs Total Score in 2017','ACT Participation Rate vs Composite Score in 2017',\
                  'SAT Participation Rate vs Total Score in 2018','ACT Participation Rate vs Composite Score in 2018',\
                  'SAT Participation Rate vs Total Score in 2019','ACT Participation Rate vs Composite Score in 2019']
x_axis_labels = ['Participation Rate','Participation Rate','Participation Rate','Participation Rate',\
                 'Participation Rate','Participation Rate']
y_axis_labels = ['Total Score','Composite Score','Total Score','Composite Score','Total Score','Composite Score']

# %%
# ACT & SAT Correlation for All Data
subplot_scatter(states_data, x_axis_scatter, y_axis_scatter, scatter_titles, y_axis_labels, x_axis_labels, 'SAT & ACT Participation Rate vs Scores')

# %% [markdown]
# *These scatterplots show there is a negative correlation between participation rates and test score performance.
# We can see this negative relationship between participation rates and SAT / ACT scores in the graphs below.  On each X-axis, you see the participation rate expressed as a decimal. On the Y-axis, you see average SAT or ACT score.  The pattern is stunningly clear: States with higher participation rates in either test almost always have much lower scores.*

# %% [markdown]
# *The SAT and ACT datasets did not display normal distributions.
# Across the board for participation rates and test scores, the distributions of the data tended to be bimodal or non-normal. That is, a majority of the data appeared at opposite ends of the distribution. For example, when observing the distribution of average SAT scores, students tended to perform either very poorly or very well. This is in contrast to a normal distribution where less students would have performed either very poorly or very well, and more students would have performed mediocrely.*
#
# *Participation Rates: The distributions of the participation rates for the SAT in both years is bimodal, with a tendency for participation rates to be the far low end of the participation rates. A majority of states experienced extremely low participation rates on the SAT, and a few experienced extremely high participation rates. In contracts, the distribution of participation for the ACT in both years was also bimodal, but there were much more states that experienced higher participation rates than lower.*

# %%
# A function to create a subplot of comparative boxplots 

def subplot_boxplot(dataframe, box1, box2, box3, list_of_titles, box1_titles, box2_titles, box3_titles, figtitle):
    nrows = int(np.ceil(len(box1)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(11, 9))  
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate  
    
    for i, (boxplot1, boxplot2, boxplot3) in enumerate(zip(box1, box2, box3)):
        ax[i].boxplot([dataframe[boxplot1],dataframe[boxplot2],dataframe[boxplot3]], widths=.7, labels = [box1_titles[i],box2_titles[i],box3_titles[i]] ) 
        for i, title in enumerate(list_of_titles):
             ax[i].set_title(title, fontsize=12)
    fig.suptitle(figtitle, size=16) 
    plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
    fig.subplots_adjust(top=.93)

# %%
# Create variables to input into boxplot function 

box1_list = ['act17_comp', 'sat17_total', 'act17_part', 'sat17_part']
box1_titles = ['ACT Composite 2017', 'SAT Total 2017', 'ACT Participation 2017', 'SAT Participation 2017']
box2_list = ['act18_comp', 'sat18_total', 'act18_part', 'sat18_part']
box2_titles = ['ACT Composite 2018', 'SAT Total 2018', 'ACT Participation 2018', 'SAT Participation 2018']
box3_list = ['act19_comp', 'sat19_total', 'act19_part', 'sat19_part']
box3_titles = ['ACT Composite 2019', 'SAT Total 2019', 'ACT Participation 2019', 'SAT Participation 2019']
box_titles = ['ACT Compositive 2017 vs 2018 vs 2019', 'SAT Total 2017 vs 2018 vs 2019', 'ACT Participation 2017 vs 2018 vs 2019', 'SAT Participation 2017 vs 2018 vs 2019']

# %%
# Boxplot Comparisons for SAT & ACT 2017-18 Scores & Participation Rates 

subplot_boxplot(states_data, box1_list, box2_list, box3_list, box_titles, box1_titles, box2_titles, box3_titles, 'Boxplot Comparisons for SAT & ACT 2017-19 Scores & Participation Rates')

# %%
def create_boxplot(data,xlabel):
    
    plt.figure(figsize=(6,6))
    g = sns.boxplot(data=data, palette=["orange", "red", "skyblue","sandybrown","green","violet"])
    g.set(xticklabels=xlabel)

# %%
# reorder columns
new_order = ['act17_part','act18_part','act19_part','sat17_part','sat18_part','sat19_part']
df_actcomp = states_data.reindex(columns=new_order)

xlabels = ['ACT 2017','ACT 2018','ACT 2019', 'SAT 2017', 'SAT 2018', 'SAT 2019']
create_boxplot(df_actcomp,xlabels)

# %%
#set order based on the following color: Urban - Orange, Suburban - Red, Rural - Blue
order = ['act17_part','act18_part','act19_part','sat17_part','sat18_part','sat19_part']
plt.figure(figsize=(8,8))
ax = sns.boxplot(x='caucus', y='unemployrate', data=ca_cleaned,\
            order=order, palette=["orange", "red", "blue","orange","green","violet"])
ax.set_title('Unemployment rates (%) by caucus in California', fontsize=15)
ax.set_xlabel('Caucus', fontsize=15)
ax.tick_params(axis='both', labelsize=12)
ax.set_ylabel('Unemployment rate (%)', fontsize=15)
plt.tight_layout()

# %%
score_gdp17 = sns.jointplot(x='sat19_total',y='gdp_2019',data=states_data,kind='reg')
plt.suptitle('SAT 2017 total score vs income')
plt.tight_layout();

# %%
sns.jointplot(x='act18_comp',y='income_2018',data=states_data,kind='reg')
plt.suptitle('ACT 2017 total score vs income')
plt.tight_layout();

# %%
sns.jointplot(x='act17_part',y='poverty_pct',data=states_data,kind='reg')
plt.suptitle('ACT 2019 participation rate vs poverty')
plt.tight_layout();

# %%
sns.jointplot(x='act19_part',y='gdp_2019',data=states_data,kind='reg')
plt.suptitle('SAT 2019 participation rate vs poverty')
plt.tight_layout();

# %%
sns.jointplot(x='sat19_part',y='income_2019',data=states_data,kind='reg')
plt.suptitle('SAT 2019 participation rate vs income')
plt.tight_layout();

# %%
sns.jointplot(x='sat19_part',y='gdp_2019',data=states_data,kind='reg')
plt.suptitle('SAT 2019 participation rate vs gdp')
plt.tight_layout();

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **To-Do:** *Edit this cell with your conclusions and recommendations.*

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
