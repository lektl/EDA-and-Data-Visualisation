# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** *Replace this cell with your problem statement.*

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def mean(numbers):
    return sum(numbers)/len(numbers)

# %%
mean([1, 3, 5, 7])
# Out:
# 4.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def std_dev(numbers):
    n = len(numbers)
    mean = sum(numbers) / n
    var = sum((i - mean) ** 2 for i in numbers) / n
    std_dev = var ** 0.5
    return std_dev

# %%
std_dev([1, 3, 5, 7])
# Out:
# 2.23606797749979

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def perc_to_float(string):
    string_num = string.replace("%","")
    return float(string_num) / 100

# %%
perc_to_float('30.5%')
# Out:
# 0.305

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
# %matplotlib inline

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# ### 1. Import and display Datasets

# %%
# Import all datasets. 
act17 = pd.read_csv("../data/act_2017.csv")
act18 = pd.read_csv("../data/act_2018.csv")
act19 = pd.read_csv("../data/act_2019.csv")
sat17 = pd.read_csv("../data/sat_2017.csv")
sat18 = pd.read_csv("../data/sat_2018.csv")
sat19 = pd.read_csv("../data/sat_2019.csv")
act19_ca = pd.read_csv("../data/act_2019_ca.csv")
sat19_ca = pd.read_csv("../data/sat_2019_ca.csv")

#Import US states GDP data from source https://apps.bea.gov/regional/downloadzip.cfm
states_gdp = pd.read_csv("../data/states_data_1997_2021.csv")

#Import median household income from source https://nces.ed.gov/programs/digest/d20/tables/dt20_102.30.asp
states_income = pd.read_csv("../data/states_income.csv")

#Import percentage of people in poverty by State using 3-Year average (2017-2019) from source https://www.census.gov/data/tables/2020/demo/income-poverty/p60-270.html
states_poverty = pd.read_csv("../data/states_poverty.csv")

# %%
act17.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
act18.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
act19.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
sat17.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
sat18.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
sat19.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
act19_ca.head()
# Out:
#             CDS  CCode     CDCode      SCode RType  \
# 0  3.366993e+13   33.0  3366993.0   129882.0     S
# 1  1.964212e+13   19.0  1964212.0  1995596.0     S
# 2  1.563776e+13   15.0  1563776.0  1530377.0     S
# 3  4.369666e+13   43.0  4369666.0  4333795.0     S
# 4  1.964733e+13   19.0  1964733.0  1935121.0     S
#
#                              SName                  DName        CName  \
# 0  21st Century Learning Institute       Beaumont Unified    Riverside
# 1      ABC Secondary (Alternative)            ABC Unified  Los Angeles
# 2      Abraham Lincoln Alternative  Southern Kern Unified         Kern
# 3             Abraham Lincoln High       San Jose Unified  Santa Clara
# 4      Abraham Lincoln Senior High    Los Angeles Unified  Los Angeles
#
#    Enroll12  NumTstTakr AvgScrRead AvgScrEng AvgScrMath AvgScrSci NumGE21  \
# 0      18.0         0.0        NaN       NaN        NaN       NaN     NaN
# 1      58.0         0.0        NaN       NaN        NaN       NaN     NaN
# 2      18.0         0.0        NaN       NaN        NaN       NaN     NaN
# 3     463.0        53.0         23        22         22        23      34
# 4     226.0        19.0         21        20         23        22      11
#
#   PctGE21     Year  Unnamed: 17
# 0     NaN  2018-19          NaN
# 1     NaN  2018-19          NaN
# 2     NaN  2018-19          NaN
# 3   64.15  2018-19          NaN
# 4   57.89  2018-19          NaN

# %%
sat19_ca.head()
# Out:
#             CDS  CCode     CDCode      SCode RType                    SName  \
# 0  6.615981e+12    6.0   661598.0   630046.0     S  Colusa Alternative Home
# 1  6.616061e+12    6.0   661606.0   634758.0     S          Maxwell Sr High
# 2  1.964733e+13   19.0  1964733.0  1930924.0     S      Belmont Senior High
# 3  1.964733e+13   19.0  1964733.0  1931476.0     S  Canoga Park Senior High
# 4  1.964733e+13   19.0  1964733.0  1931856.0     S     Whitman Continuation
#
#                  DName        CName  Enroll12  NumTSTTakr12  ...  \
# 0       Colusa Unified       Colusa      18.0           0.0  ...
# 1      Maxwell Unified       Colusa      29.0          10.0  ...
# 2  Los Angeles Unified  Los Angeles     206.0         102.0  ...
# 3  Los Angeles Unified  Los Angeles     227.0         113.0  ...
# 4  Los Angeles Unified  Los Angeles      18.0          14.0  ...
#
#   NumERWBenchmark11 PctERWBenchmark11 NumMathBenchmark11 PctMathBenchmark11  \
# 0               NaN               NaN                NaN                NaN
# 1                 *                 *                  *                  *
# 2                42             24.14                 12               6.90
# 3                97             35.27                 37              13.45
# 4                 *                 *                  *                  *
#
#    TotNumBothBenchmark12  PctBothBenchmark12 TotNumBothBenchmark11  \
# 0                    NaN                 NaN                   NaN
# 1                      *                   *                     *
# 2                     14               13.73                    11
# 3                     18               15.93                    35
# 4                      *                   *                     *
#
#   PctBothBenchmark11     Year Unnamed: 25
# 0                NaN  2018-19         NaN
# 1                  *  2018-19         NaN
# 2               6.32  2018-19         NaN
# 3              12.73  2018-19         NaN
# 4                  *  2018-19         NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# ### 2. Check for missing values

# %%
#Check for missing values in ACT 2017- 2019
act17.isnull().sum(),act18.isnull().sum(),act19.isnull().sum()
# Out:
# (State            0
#  Participation    0
#  English          0
#  Math             0
#  Reading          0
#  Science          0
#  Composite        0
#  dtype: int64,
#  State            0
#  Participation    0
#  Composite        0
#  dtype: int64,
#  State            0
#  Participation    0
#  Composite        0
#  dtype: int64)

# %%
#Check for missing values in SAT 2017- 2019
sat17.isnull().sum(),sat18.isnull().sum(),sat19.isnull().sum()
# Out:
# (State                                 0
#  Participation                         0
#  Evidence-Based Reading and Writing    0
#  Math                                  0
#  Total                                 0
#  dtype: int64,
#  State                                 0
#  Participation                         0
#  Evidence-Based Reading and Writing    0
#  Math                                  0
#  Total                                 0
#  dtype: int64,
#  State                 0
#  Participation Rate    0
#  EBRW                  0
#  Math                  0
#  Total                 0
#  dtype: int64)

# %%
#Check for missing values in ACT CA 2019
act19_ca.isnull().sum()
# Out:
# CDS               1
# CCode             1
# CDCode            1
# SCode           523
# RType             1
# SName           581
# DName            59
# CName             1
# Enroll12          1
# NumTstTakr        1
# AvgScrRead      357
# AvgScrEng       357
# AvgScrMath      357
# AvgScrSci       357
# NumGE21         357
# PctGE21         357
# Year              1
# Unnamed: 17    2310
# dtype: int64

# %%
#Check for missing values in SAT CA 2019
sat19_ca.isnull().sum()
# Out:
# CDS                         1
# CCode                       1
# CDCode                      1
# SCode                       1
# RType                       1
# SName                     598
# DName                      59
# CName                       1
# Enroll12                    1
# NumTSTTakr12                1
# NumERWBenchmark12         276
# PctERWBenchmark12         276
# NumMathBenchmark12        276
# PctMathBenchmark12        276
# Enroll11                    1
# NumTSTTakr11                1
# NumERWBenchmark11         311
# PctERWBenchmark11         311
# NumMathBenchmark11        311
# PctMathBenchmark11        311
# TotNumBothBenchmark12     276
# PctBothBenchmark12        276
# TotNumBothBenchmark11     311
# PctBothBenchmark11        311
# Year                        1
# Unnamed: 25              2580
# dtype: int64

# %% [markdown]
# ### 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).

# %% [markdown]
# **a) Checking the Min/Max Values in ACT 2017 - 2019**
#
# The range of scores for the ACT should be between 1-36.

# %%
print(act17.min(), act17.max())
# Out:
# State            Alabama
# Participation        60%
# English             16.3
# Math                18.0
# Reading             18.1
# Science              2.3
# Composite           17.8
# dtype: object State            Wyoming
# Participation        98%
# English             25.5
# Math                25.3
# Reading             26.0
# Science             24.9
# Composite           25.5
# dtype: object

# %%
print(act18.min(), act18.max())
# Out:
# State            Alabama
# Participation       100%
# Composite           17.7
# dtype: object State            Wyoming
# Participation        99%
# Composite           25.6
# dtype: object

# %%
print(act19.min(), act19.max())
# Out:
# State            Alabama
# Participation       100%
# Composite           17.9
# dtype: object State            Wyoming
# Participation        96%
# Composite           25.5
# dtype: object

# %% [markdown]
# **b) Checking the Min/Max Values in SAT 2017 - 2019**
#
# The range of scores for the SAT should be between 200-800.

# %%
print(sat17.min(), sat17.max())
# Out:
# State                                 Alabama
# Participation                             10%
# Evidence-Based Reading and Writing        482
# Math                                       52
# Total                                     950
# dtype: object State                                 Wyoming
# Participation                             96%
# Evidence-Based Reading and Writing        644
# Math                                      651
# Total                                    1295
# dtype: object

# %%
print(sat18.min(), sat18.max())
# Out:
# State                                 Alabama
# Participation                             10%
# Evidence-Based Reading and Writing        480
# Math                                      480
# Total                                     977
# dtype: object State                                 Wyoming
# Participation                             99%
# Evidence-Based Reading and Writing        643
# Math                                      655
# Total                                    1298
# dtype: object

# %%
print(sat19.min(), sat19.max())
# Out:
# State                 Alabama
# Participation Rate       100%
# EBRW                      483
# Math                      445
# Total                     935
# dtype: object State                 Wyoming
# Participation Rate          —
# EBRW                      636
# Math                      648
# Total                    1284
# dtype: object

# %% [markdown]
# ### 4. Fix any errors identified in Steps 2-3

# %% [markdown]
# From step 3, there seems to be an error with the SAT 2017 min Math score of 52 which is out of the range of 200 - 800.

# %%
sat17.sort_values(['Math']).head(1)
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %% [markdown]
# To get the correct Math score, we subtract the writing score from the total score.
# The correct Math score for the State of Maryland should be 524.

# %%
# Assign the new value to the state of Maryland
sat17.loc[20,'Math'] = 524

# Check the score to make sure value has been replaced
sat17['Math'][20]
# Out:
# 524

# %% [markdown]
# ### 5. Display data types of each feature

# %%
act17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
act18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
act19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
sat17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
act19_ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2310 entries, 0 to 2309
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CDS          2309 non-null   float64
#  1   CCode        2309 non-null   float64
#  2   CDCode       2309 non-null   float64
#  3   SCode        1787 non-null   float64
#  4   RType        2309 non-null   object
#  5   SName        1729 non-null   object
#  6   DName        2251 non-null   object
#  7   CName        2309 non-null   object
#  8   Enroll12     2309 non-null   float64
#  9   NumTstTakr   2309 non-null   float64
#  10  AvgScrRead   1953 non-null   object
#  11  AvgScrEng    1953 non-null   object
#  12  AvgScrMath   1953 non-null   object
#  13  AvgScrSci    1953 non-null   object
#  14  NumGE21      1953 non-null   object
#  15  PctGE21      1953 non-null   object
#  16  Year         2309 non-null   object
#  17  Unnamed: 17  0 non-null      float64
# dtypes: float64(7), object(11)
# memory usage: 325.0+ KB

# %%
sat19_ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CDS                    2579 non-null   float64
#  1   CCode                  2579 non-null   float64
#  2   CDCode                 2579 non-null   float64
#  3   SCode                  2579 non-null   float64
#  4   RType                  2579 non-null   object
#  5   SName                  1982 non-null   object
#  6   DName                  2521 non-null   object
#  7   CName                  2579 non-null   object
#  8   Enroll12               2579 non-null   float64
#  9   NumTSTTakr12           2579 non-null   float64
#  10  NumERWBenchmark12      2304 non-null   object
#  11  PctERWBenchmark12      2304 non-null   object
#  12  NumMathBenchmark12     2304 non-null   object
#  13  PctMathBenchmark12     2304 non-null   object
#  14  Enroll11               2579 non-null   float64
#  15  NumTSTTakr11           2579 non-null   float64
#  16  NumERWBenchmark11      2269 non-null   object
#  17  PctERWBenchmark11      2269 non-null   object
#  18  NumMathBenchmark11     2269 non-null   object
#  19  PctMathBenchmark11     2269 non-null   object
#  20  TotNumBothBenchmark12  2304 non-null   object
#  21  PctBothBenchmark12     2304 non-null   object
#  22  TotNumBothBenchmark11  2269 non-null   object
#  23  PctBothBenchmark11     2269 non-null   object
#  24  Year                   2579 non-null   object
#  25  Unnamed: 25            0 non-null      float64
# dtypes: float64(9), object(17)
# memory usage: 524.2+ KB

# %% [markdown]
# ### 6. Fix any incorrect data types

# %% [markdown]
# **a) Fix data type for ACT 2017**

# %%
#Change from Percentage to float
act17['Participation'] = act17['Participation'].map(perc_to_float)

#Replace Wyoming Composite from 20.2x to 20.2
act17['Composite'] = act17['Composite'].replace(['20.2x'],20.2)
act17['Composite'] = pd.to_numeric(act17['Composite'])

# %%
act17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %% [markdown]
# **b) Fix data type for ACT 2018**

# %%
#Change from Percentage to float
act18['Participation'] = act18['Participation'].map(perc_to_float)

# %%
act18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   Composite      52 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# **c) Fix data type for ACT 2019**

# %%
#Change from Percentage to float
act19['Participation'] = act19['Participation'].map(perc_to_float)

# %%
act19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   Composite      52 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# **d) Fix data type for SAT 2017**

# %%
#Change from Percentage to float
sat17['Participation'] = sat17['Participation'].map(perc_to_float)

# %%
sat17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# **e) Fix data type for SAT 2018**

# %%
#Change from Percentage to float
sat18['Participation'] = sat18['Participation'].map(perc_to_float)

# %%
sat18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# **f) Fix data type for SAT 2019**

# %%
#Removal of Virgin island and Puerto Rico
sat19.drop(sat19[sat19['State']=="Puerto Rico"].index, inplace=True)
sat19.drop(sat19[sat19['State']=="Virgin Islands"].index, inplace=True)

#Change from Percentage to float
sat19['Participation Rate'] = sat19['Participation Rate'].map(perc_to_float)

# %%
sat19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               51 non-null     object
#  1   Participation Rate  51 non-null     float64
#  2   EBRW                51 non-null     int64
#  3   Math                51 non-null     int64
#  4   Total               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.4+ KB

# %% [markdown]
# ### 7. Rename Columns

# %% [markdown]
# For ACT 2017 to 2019

# %%
#Change column names to lowercase.
act17_columns_list = [
    'state',
    'act17_part',
    'act17_eng',
    'act17_math',
    'act17_read',
    'act17_sci',
    'act17_comp'
]

act18_columns_list = [
    'state',
    'act18_part',
    'act18_comp'
]

act19_columns_list = [
    'state',
    'act19_part',
    'act19_comp'
]

act17.columns = act17_columns_list
act18.columns = act18_columns_list
act19.columns = act19_columns_list

# %% [markdown]
# For SAT 2017 to 2019

# %%
#Change column names to lowercase.
sat17_columns_list = [
    'state',
    'sat17_part',
    'sat17_ebrw',
    'sat17_math',
    'sat17_total'
]

sat18_columns_list = [
    'state',
    'sat18_part',
    'sat18_ebrw',
    'sat18_math',
    'sat18_total'
]

sat19_columns_list = [
    'state',
    'sat19_part',
    'sat19_ebrw',
    'sat19_math',
    'sat19_total'
]

sat17.columns = sat17_columns_list
sat18.columns = sat18_columns_list
sat19.columns = sat19_columns_list

# %% [markdown]
# ### 8. Drop unnecesary rows

# %% [markdown]
# For ACT 2017

# %%
#Check for duplicate entries
duplicateRowsDF = act17[act17.duplicated()]
print(duplicateRowsDF)
# Out:
# Empty DataFrame
# Columns: [state, act17_part, act17_eng, act17_math, act17_read, act17_sci, act17_comp]
# Index: []

# %%
#Remove "National" as it's not a  state
act17.drop(act17[act17['state']=="National"].index, inplace=True)
#Reset and drop index
act17 = act17.reset_index(drop = True)

# %% [markdown]
# For ACT 2018

# %%
#Check for duplicate entries
duplicateRowsDF = act18[act18.duplicated()]
print(duplicateRowsDF)
# Out:
#     state  act18_part  act18_comp
# 20  Maine        0.07        24.0

# %%
#Changing "District of columbia" to "District of Columbia"
act18['state'] = act18['state'].replace(['District of columbia'],'District of Columbia')

#Drop duplicates
act18 = act18.drop_duplicates()

#Reset index
act18 = act18.reset_index(drop = True)

# %% [markdown]
# For ACT 2019

# %%
#Check for duplicate entries
duplicateRowsDF = act19[act19.duplicated()]
print(duplicateRowsDF)
# Out:
# Empty DataFrame
# Columns: [state, act19_part, act19_comp]
# Index: []

# %%
#Remove National row from act19
act19.drop(act19[act19['state']=="National"].index, inplace=True)

#Reset index
act19 = act19.reset_index(drop = True)

# %% [markdown]
# For SAT 2017

# %%
#Check for duplicate entries
duplicateRowsDF = sat17[sat17.duplicated()]
print(duplicateRowsDF)
# Out:
# Empty DataFrame
# Columns: [state, sat17_part, sat17_ebrw, sat17_math, sat17_total]
# Index: []

# %% [markdown]
# For SAT 2018

# %%
#Check for duplicate entries
duplicateRowsDF = sat18[sat18.duplicated()]
print(duplicateRowsDF)
# Out:
# Empty DataFrame
# Columns: [state, sat18_part, sat18_ebrw, sat18_math, sat18_total]
# Index: []

# %% [markdown]
# For SAT 2019

# %%
#Check for duplicate entries
duplicateRowsDF = sat19[sat19.duplicated()]
print(duplicateRowsDF)
# Out:
# Empty DataFrame
# Columns: [state, sat19_part, sat19_ebrw, sat19_math, sat19_total]
# Index: []

# %% [markdown]
# ### 9. Merge dataframes that can be  merged

# %%
#Merge ACT and SAT datasets for 2017, 2018 and 2019.

sat_act_17 = sat17.merge(act17, how = "outer", on = "state")
sat_act_18 = sat18.merge(act18, how = "outer", on = "state")
sat_act_19 = sat19.merge(act19, how = "outer", on = "state")

combined_sat_act = pd.merge(pd.merge(sat_act_17,sat_act_18, on = 'state'), sat_act_19, on = 'state')

# %%
combined_sat_act.shape
# Out:
# (51, 23)

# %%
combined_sat_act.head()
# Out:
#         state  sat17_part  sat17_ebrw  sat17_math  sat17_total  act17_part  \
# 0     Alabama        0.05         593         572         1165        1.00
# 1      Alaska        0.38         547         533         1080        0.65
# 2     Arizona        0.30         563         553         1116        0.62
# 3    Arkansas        0.03         614         594         1208        1.00
# 4  California        0.53         531         524         1055        0.31
#
#    act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  sat18_total  \
# 0       18.9        18.4        19.7       19.4  ...         571         1166
# 1       18.7        19.8        20.4       19.9  ...         544         1106
# 2       18.6        19.8        20.1       19.8  ...         572         1149
# 3       18.9        19.0        19.7       19.5  ...         576         1169
# 4       22.5        22.7        23.1       22.2  ...         536         1076
#
#    act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  sat19_total  \
# 0        1.00        19.1        0.07         583         560         1143
# 1        0.33        20.8        0.41         556         541         1097
# 2        0.66        19.2        0.31         569         565         1134
# 3        1.00        19.4        0.06         582         559         1141
# 4        0.27        22.7        0.63         534         531         1065
#
#    act19_part  act19_comp
# 0        1.00        18.9
# 1        0.38        20.1
# 2        0.73        19.0
# 3        1.00        19.3
# 4        0.23        22.6
#
# [5 rows x 23 columns]

# %% [markdown]
# ### 10. Perform any additional cleaning

# %% [markdown]
# *Clean dataset for ACT CA 2019*

# %%
act19_ca.head()
# Out:
#             CDS  CCode     CDCode      SCode RType  \
# 0  3.366993e+13   33.0  3366993.0   129882.0     S
# 1  1.964212e+13   19.0  1964212.0  1995596.0     S
# 2  1.563776e+13   15.0  1563776.0  1530377.0     S
# 3  4.369666e+13   43.0  4369666.0  4333795.0     S
# 4  1.964733e+13   19.0  1964733.0  1935121.0     S
#
#                              SName                  DName        CName  \
# 0  21st Century Learning Institute       Beaumont Unified    Riverside
# 1      ABC Secondary (Alternative)            ABC Unified  Los Angeles
# 2      Abraham Lincoln Alternative  Southern Kern Unified         Kern
# 3             Abraham Lincoln High       San Jose Unified  Santa Clara
# 4      Abraham Lincoln Senior High    Los Angeles Unified  Los Angeles
#
#    Enroll12  NumTstTakr AvgScrRead AvgScrEng AvgScrMath AvgScrSci NumGE21  \
# 0      18.0         0.0        NaN       NaN        NaN       NaN     NaN
# 1      58.0         0.0        NaN       NaN        NaN       NaN     NaN
# 2      18.0         0.0        NaN       NaN        NaN       NaN     NaN
# 3     463.0        53.0         23        22         22        23      34
# 4     226.0        19.0         21        20         23        22      11
#
#   PctGE21     Year  Unnamed: 17
# 0     NaN  2018-19          NaN
# 1     NaN  2018-19          NaN
# 2     NaN  2018-19          NaN
# 3   64.15  2018-19          NaN
# 4   57.89  2018-19          NaN

# %%
#Filter out rows with RType = C, as only county data is required
act19_ca = act19_ca[act19_ca['RType']=='C']

#Drop unnecessary columns
act19_ca.drop(columns=['Unnamed: 17','CDCode','SCode','RType','SName','DName'], inplace = True)

#Change columns name to lowercase
act19_ca_columns_name = [
    'cds',
    'ccode',
    'cname',
    'enroll',
    'num_tst_takr',
    'avg_scr_read',
    'avg_scr_eng',
    'avg_scr_math',
    'avg_scr_sci',
    'num_ge_21',
    'pct_ge_21',
    'year'
]

act19_ca.columns = act19_ca_columns_name

#Change 2018-2019 to 2019 for "year" column
act19_ca['year'] = int(2019)

#Reset index
act19_ca = act19_ca.reset_index(drop = True)

#Replace '*' to NaN
act19_ca = act19_ca.replace('*',np.nan)

#Convert columns to numeric
act19_ca_cols = ['avg_scr_read','avg_scr_eng','avg_scr_math','avg_scr_sci','num_ge_21','pct_ge_21','year']
act19_ca[act19_ca_cols] = act19_ca[act19_ca_cols].apply(pd.to_numeric)

#Sort columns by County name in alphabetical order
act19_ca = act19_ca.sort_values('cname', ascending = True)

# %%
act19_ca.head()
# Out:
#              cds  ccode      cname   enroll  num_tst_takr  avg_scr_read  \
# 42  1.000000e+12    1.0    Alameda  17567.0        3630.0          25.0
# 39  2.000000e+12    2.0     Alpine      0.0           0.0           NaN
# 27  3.000000e+12    3.0     Amador    305.0          37.0          24.0
# 33  4.000000e+12    4.0      Butte   2551.0         226.0          23.0
# 5   5.000000e+12    5.0  Calaveras    451.0          31.0          26.0
#
#     avg_scr_eng  avg_scr_math  avg_scr_sci  num_ge_21  pct_ge_21  year
# 42         24.0          24.0         24.0     2459.0      67.74  2019
# 39          NaN           NaN          NaN        NaN        NaN  2019
# 27         23.0          23.0         22.0       29.0      78.38  2019
# 33         22.0          23.0         23.0      146.0      64.60  2019
# 5          24.0          24.0         24.0       27.0      87.10  2019

# %% [markdown]
# *Clean dataset for SAT CA 2019*

# %%
#Filter out rows with RType = C, as only county data is required
sat19_ca = sat19_ca[sat19_ca['RType']=='C']

#Drop unnecessary columns
drop_columns = ['Unnamed: 25','CDCode','SCode','RType','SName','DName','Enroll11','NumTSTTakr11','NumERWBenchmark11','PctERWBenchmark11','NumMathBenchmark11','PctMathBenchmark11','TotNumBothBenchmark11','PctBothBenchmark11']
sat19_ca.drop(columns=drop_columns, inplace=True)

#Change columns name to lowercase
sat19_ca_columns_name = [
    'cds',
    'ccode',
    'cname',
    'enroll',
    'num_tst_takr',
    'num_erw_bm',
    'pct_erw_bm',
    'num_math_bm',
    'pct_math_bm',
    'tot_num_both_bm',
    'pct_both_bm',
    'year'
]

sat19_ca.columns = sat19_ca_columns_name

#Change 2018-2019 to 2019 for "year" column
sat19_ca['year'] = int(2019)

#Reset index
sat19_ca = sat19_ca.reset_index(drop = True)

#Replace '*' to NaN
sat19_ca = sat19_ca.replace('*',np.nan)

#Convert columns to numeric
sat19_ca_cols = ['num_erw_bm','pct_erw_bm','num_math_bm','pct_math_bm','tot_num_both_bm','pct_both_bm','year']
sat19_ca[sat19_ca_cols] = sat19_ca[sat19_ca_cols].apply(pd.to_numeric)

#Sort columns by County name in alphabetical order
sat19_ca = sat19_ca.sort_values('cname', ascending = True)

# %%
sat19_ca.head()
# Out:
#              cds  ccode      cname   enroll  num_tst_takr  num_erw_bm  \
# 23  1.000000e+12    1.0    Alameda  17567.0        5946.0      4566.0
# 31  2.000000e+12    2.0     Alpine      0.0           0.0         NaN
# 32  3.000000e+12    3.0     Amador    305.0          53.0        44.0
# 45  4.000000e+12    4.0      Butte   2551.0         551.0       453.0
# 10  5.000000e+12    5.0  Calaveras    451.0          90.0        81.0
#
#     pct_erw_bm  num_math_bm  pct_math_bm  tot_num_both_bm  pct_both_bm  year
# 23       76.79       3623.0        60.93           3458.0        58.16  2019
# 31         NaN          NaN          NaN              NaN          NaN  2019
# 32       83.02         35.0        66.04             33.0        62.26  2019
# 45       82.21        349.0        63.34            332.0        60.25  2019
# 10       90.00         60.0        66.67             60.0        66.67  2019

# %% [markdown]
# ### Cleaning datasets for States' median household income, poverty and GDP

# %% [markdown]
# *Cleaning median household income*

# %%
states_income.head(3)
# Out:
#      State    2017    2018    2019
# 0  Alabama  50,200  50,800  51,700
# 1   Alaska  76,300  75,700  75,500
# 2  Arizona  59,000  60,300  62,100

# %%
#Remove commas
states_income = states_income.replace(',','', regex=True)

#Change columns name
states_income.rename(columns = {'State':'state', '2017':'income_2017', '2018':'income_2018','2019':'income_2019'}, inplace = True)

#Change data type to float
states_income[['income_2017','income_2018','income_2019']] = states_income[['income_2017','income_2018','income_2019']].astype(float)

#Check for duplicate rows
duplicateRowsDF = states_income[states_income.duplicated()]
print(duplicateRowsDF)

#Reset index
states_income = states_income.reset_index(drop = True)

states_income.info()
# Out:
# Empty DataFrame
# Columns: [state, income_2017, income_2018, income_2019]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        51 non-null     object
#  1   income_2017  51 non-null     float64
#  2   income_2018  51 non-null     float64
#  3   income_2019  51 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 1.7+ KB

# %% [markdown]
# *Cleaning poverty data*

# %%
states_poverty.head(3)
# Out:
#      State  Percentage
# 0  Alabama        14.7
# 1   Alaska        11.8
# 2  Arizona        12.1

# %%
#Change columns name
states_poverty.rename(columns = {'State':'state', 'Percentage':'poverty_pct'}, inplace = True)

#Check for duplicate rows
duplicateRowsDF = states_poverty[states_poverty.duplicated()]
print(duplicateRowsDF)

#Reset index
states_poverty = states_poverty.reset_index(drop = True)

states_poverty.info()
# Out:
# Empty DataFrame
# Columns: [state, poverty_pct]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        51 non-null     object
#  1   poverty_pct  51 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 944.0+ bytes

# %% [markdown]
# *Cleaning GDP data*

# %%
states_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   GeoName      408 non-null    object
#  1   Description  408 non-null    object
#  2   2017         408 non-null    float64
#  3   2018         408 non-null    float64
#  4   2019         408 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 16.1+ KB

# %%
#Filter out required rows
states_gdp = states_gdp[states_gdp['Description'].str.contains('Current-dollar GDP', na=False)]

#Remove Description and Unit column from states_gdp
states_gdp = states_gdp.drop(columns =['Description'])

#Reset and drop index
states_gdp = states_gdp.reset_index(drop = True)

#Rename columns heading
states_gdp.rename(columns = {'GeoName':'state', '2017':'gdp_2017', '2018':'gdp_2018', '2019':'gdp_2019'}, inplace = True)

#Check for duplicate entries
duplicateRowsDF = states_gdp[states_gdp.duplicated()]
print(duplicateRowsDF)

states_gdp.info()
# Out:
# Empty DataFrame
# Columns: [state, gdp_2017, gdp_2018, gdp_2019]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   state     51 non-null     object
#  1   gdp_2017  51 non-null     float64
#  2   gdp_2018  51 non-null     float64
#  3   gdp_2019  51 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 1.7+ KB

# %%
merged_1 = pd.merge(states_income, states_gdp, on = 'state')
merged_2 = pd.merge(states_poverty, merged_1, on = 'state')
states_data = pd.merge(combined_sat_act, merged_2, on = 'state')
states_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 30 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        51 non-null     object
#  1   sat17_part   51 non-null     float64
#  2   sat17_ebrw   51 non-null     int64
#  3   sat17_math   51 non-null     int64
#  4   sat17_total  51 non-null     int64
#  5   act17_part   51 non-null     float64
#  6   act17_eng    51 non-null     float64
#  7   act17_math   51 non-null     float64
#  8   act17_read   51 non-null     float64
#  9   act17_sci    51 non-null     float64
#  10  act17_comp   51 non-null     float64
#  11  sat18_part   51 non-null     float64
#  12  sat18_ebrw   51 non-null     int64
#  13  sat18_math   51 non-null     int64
#  14  sat18_total  51 non-null     int64
#  15  act18_part   51 non-null     float64
#  16  act18_comp   51 non-null     float64
#  17  sat19_part   51 non-null     float64
#  18  sat19_ebrw   51 non-null     int64
#  19  sat19_math   51 non-null     int64
#  20  sat19_total  51 non-null     int64
#  21  act19_part   51 non-null     float64
#  22  act19_comp   51 non-null     float64
#  23  poverty_pct  51 non-null     float64
#  24  income_2017  51 non-null     float64
#  25  income_2018  51 non-null     float64
#  26  income_2019  51 non-null     float64
#  27  gdp_2017     51 non-null     float64
#  28  gdp_2018     51 non-null     float64
#  29  gdp_2019     51 non-null     float64
# dtypes: float64(20), int64(9), object(1)
# memory usage: 12.4+ KB

# %%
states_data.head()
# Out:
#         state  sat17_part  sat17_ebrw  sat17_math  sat17_total  act17_part  \
# 0     Alabama        0.05         593         572         1165        1.00
# 1      Alaska        0.38         547         533         1080        0.65
# 2     Arizona        0.30         563         553         1116        0.62
# 3    Arkansas        0.03         614         594         1208        1.00
# 4  California        0.53         531         524         1055        0.31
#
#    act17_eng  act17_math  act17_read  act17_sci  ...  sat19_total  act19_part  \
# 0       18.9        18.4        19.7       19.4  ...         1143        1.00
# 1       18.7        19.8        20.4       19.9  ...         1097        0.38
# 2       18.6        19.8        20.1       19.8  ...         1134        0.73
# 3       18.9        19.0        19.7       19.5  ...         1141        1.00
# 4       22.5        22.7        23.1       22.2  ...         1065        0.23
#
#    act19_comp  poverty_pct  income_2017  income_2018  income_2019   gdp_2017  \
# 0        18.9         14.7      50200.0      50800.0      51700.0   215085.9
# 1        20.1         11.8      76300.0      75700.0      75500.0    53089.3
# 2        19.0         12.1      59000.0      60300.0      62100.0   330416.1
# 3        19.3         15.0      47800.0      47900.0      49000.0   122350.2
# 4        22.6         11.4      74900.0      76600.0      80400.0  2730973.9
#
#     gdp_2018   gdp_2019
# 0   224046.9   231171.8
# 1    54711.7    54547.1
# 2   349907.5   369988.2
# 3   127306.5   130839.9
# 4  2895101.0  3052645.2
#
# [5 rows x 30 columns]

# %% [markdown]
# ### 11. Save cleaned and merged dataframes as csv file

# %%
#Save the clean and merged datasets
sat_act_17.to_csv('../data/sat_act_17.csv')
sat_act_18.to_csv('../data/sat_act_18.csv')
sat_act_19.to_csv('../data/sat_act_19.csv')
sat19_ca.to_csv('../data/cleaned_sat19_ca.csv')
act19_ca.to_csv('../data/cleaned_act19_ca.csv')

combined_sat_act.to_csv('../data/combined_sat_act.csv')

states_data.to_csv('../data/states_data.csv')

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# **Data Dictionary for ACT 2017, SAT 2017**
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|obj|ACT/SAT|State|
# |sat17_part|float64|ACT/SAT|Statewide SAT Participation Rate, 2017|
# |sat17_ebrw|int64|ACT/SAT|State mean score, SAT Reading/Writing (200-800), 2017|
# |sat17_math|int64|ACT/SAT|State mean score, SAT Math (200-800), 2017|
# |sat17_total|int64|ACT/SAT|State mean total SAT score (400-1600), 2017|
# |act17_part|float64|ACT/SAT|Statewide ACT Participation Rate, 2017|
# |act17_eng|float64|ACT/SAT|State mean score, ACT English (1-36), 2017|
# |act17_math|float64|ACT/SAT|State mean score, ACT English (1-36), 2017|
# |act17_read|float64|ACT/SAT|State mean score, ACT Reading (1-36), 2017|
# |act17_sci|float64|ACT/SAT|State mean score, ACT Science (1-36), 2017|
# |act17_comp|float64|ACT/SAT|State mean ACT Composite Score (1-36), 2017|

# %% [markdown]
# **Data Dictionary for ACT 2018, SAT 2018**
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|obj|ACT/SAT|State|
# |sat18_part|float64|ACT/SAT|Statewide SAT Participation Rate, 2018|
# |sat18_ebrw|int64|ACT/SAT|State mean score, SAT Reading/Writing (200-800), 2018|
# |sat18_math|int64|ACT/SAT|State mean score, SAT Math (200-800), 2018|
# |sat18_total|int64|ACT/SAT|State mean total SAT score (400-1600), 2018|
# |act18_part|float64|ACT/SAT|Statewide ACT Participation Rate, 2018|
# |act18_eng|float64|ACT/SAT|State mean score, ACT English (1-36), 2018|
# |act18_math|float64|ACT/SAT|State mean score, ACT English (1-36), 2018|
# |act18_read|float64|ACT/SAT|State mean score, ACT Reading (1-36), 2018|
# |act18_sci|float64|ACT/SAT|State mean score, ACT Science (1-36), 2018|
# |act18_comp|float64|ACT/SAT|State mean ACT Composite Score (1-36), 2018|

# %% [markdown]
# **Data Dictionary for ACT 2019, SAT 2019**
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|obj|ACT/SAT|State|
# |sat19_part|float64|ACT/SAT|Statewide SAT Participation Rate, 2019|
# |sat19_ebrw|int64|ACT/SAT|State mean score, SAT Reading/Writing (200-800), 2019|
# |sat19_math|int64|ACT/SAT|State mean score, SAT Math (200-800), 2019|
# |sat19_total|int64|ACT/SAT|State mean total SAT score (400-1600), 2019|
# |act19_part|float64|ACT/SAT|Statewide ACT Participation Rate, 2019|
# |act19_eng|float64|ACT/SAT|State mean score, ACT English (1-36), 2019|
# |act19_math|float64|ACT/SAT|State mean score, ACT English (1-36), 2019|
# |act19_read|float64|ACT/SAT|State mean score, ACT Reading (1-36), 2019|
# |act19_sci|float64|ACT/SAT|State mean score, ACT Science (1-36), 2019|
# |act19_comp|float64|ACT/SAT|State mean ACT Composite Score (1-36), 2019|

# %% [markdown]
# **Data Dictionary for ACT 2019 California**
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |cds|obj|ACT 2019 CA|County/District/School Code|
# |ccode|float64|ACT 2019 CA|County Code|
# |cname|int64|ACT 2019 CA|County Name|
# |enroll|int64|ACT 2019 CA|Enrollment of Grade 12|
# |num_tst_takr|int64|ACT 2019 CA|Number of Test Takers of Grade 12|
# |avg_scr_read|float64|ACT 2019 CA|State mean score, ACT Reading (1-36), 2019|
# |avg_scr_eng|float64|ACT 2019 CA|State mean score, ACT English (1-36), 2019|
# |avg_scr_math|float64|ACT 2019 CA|State mean score, ACT Math (1-36), 2019|
# |avg_scr_sci|float64|ACT 2019 CA|State mean score, ACT Science (1-36), 2019|
# |num_ge_21|float64|ACT 2019 CA|Number of Test Takers Whose ACT Composite Scores Are Greater or Equal to 21|
# |pct_ge_21|float64|ACT 2019 CA|Percent of Test Takers Whose ACT Composite Scores Are Greater or Equal to 21|
# |year|float64|ACT 2019 CA|Test Administration Academic Year|

# %% [markdown]
# **Data Dictionary for SAT 2019 California**
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |cds|obj|SAT 2019 CA|County/District/School Code|
# |ccode|float64|SAT 2019 CA|County Code|
# |cname|int64|SAT 2019 CA|County Name|
# |enroll|int64|SAT 2019 CA|Enrollment of Grade 12|
# |num_tst_takr|int64|SAT 2019 CA|Number of Test Takers of Grade 12|
# |num_erw_bm|float64|SAT 2019 CA|The number of students who met or exceeded the benchmark for SAT Evidence-Based Reading & Writing (ERW) test|
# |pct_erw_bm|float64|SAT 2019 CA|The percent of students who met or exceeded the benchmark for Evidence-Based Reading & Writing (ERW)|
# |num_math_bm|float64|SAT 2019 CA|The number of students who met or exceeded the benchmark for SAT Math test|
# |pct_math_bm|float64|SAT 2019 CA|The percent of students who met or exceeded the benchmark for SAT Math test|
# |tot_num_both_bm|float64|SAT 2019 CA|The total number of students who met the benchmark of both Evidence-Based Reading & Writing (ERW) and Math|
# |pct_both_bm|float64|SAT 2019 CA|The percent of students who met the benchmark of both Evidence-Based Reading & Writing (ERW) and Math), 2019|
# |year|float64|SAT 2019 CA|Test Administration Academic Year|

# %% [markdown]
# **Data Dictionary for States Data**
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|obj|STATES DATA|State|
# |poverty_pct|float64|STATES DATA|Poverty 3-year average percentage, 2017-2019|
# |income_2017|float64|STATES DATA|Median household income for 2017|
# |income_2018|float64|STATES DATA|Median household income for 2018|
# |income_2019|float64|STATES DATA|Median household income for 2019|
# |gdp_2017|float64|STATES DATA|Current-dollar GDP for 2017|
# |gdp_2018|float64|STATES DATA|Current-dollar GDP for 2018|
# |gdp_2019|float64|STATES DATA|Current-dollar GDP for 2019|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - a
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### 1. Summary Statistics

# %%
states_data.describe().round(2)
# Out:
#        sat17_part  sat17_ebrw  sat17_math  sat17_total  act17_part  act17_eng  \
# count       51.00       51.00       51.00        51.00       51.00      51.00
# mean         0.40      569.12      556.88      1126.10        0.65      20.93
# std          0.35       45.67       47.12        92.49        0.32       2.35
# min          0.02      482.00      468.00       950.00        0.08      16.30
# 25%          0.04      533.50      523.50      1055.50        0.31      19.00
# 50%          0.38      559.00      548.00      1107.00        0.69      20.70
# 75%          0.66      613.00      599.00      1212.00        1.00      23.30
# max          1.00      644.00      651.00      1295.00        1.00      25.50
#
#        act17_math  act17_read  act17_sci  act17_comp  ...  sat19_total  \
# count       51.00       51.00      51.00       51.00  ...        51.00
# mean        21.18       22.01      21.04       21.52  ...      1113.08
# std          1.98        2.07       3.18        2.02  ...        97.20
# min         18.00       18.10       2.30       17.80  ...       943.00
# 25%         19.40       20.45      19.90       19.80  ...      1038.00
# 50%         20.90       21.80      21.30       21.40  ...      1097.00
# 75%         23.10       24.15      22.75       23.60  ...      1210.00
# max         25.30       26.00      24.90       25.50  ...      1284.00
#
#        act19_part  act19_comp  poverty_pct  income_2017  income_2018  \
# count       51.00       51.00        51.00        51.00        51.00
# mean         0.59       21.46        11.27     62819.61     63137.25
# std          0.35        2.19         2.83     10691.66     10801.87
# min          0.06       17.90         5.60     45300.00     44900.00
# 25%          0.24       19.80         9.55     55350.00     56400.00
# 50%          0.54       21.10        10.60     61100.00     61000.00
# 75%          1.00       23.70        12.55     71300.00     72150.00
# max          1.00       25.50        19.10     85900.00     86700.00
#
#        income_2019    gdp_2017    gdp_2018    gdp_2019
# count        51.00       51.00       51.00       51.00
# mean      65513.73   379812.02   400047.75   416520.21
# std       11171.02   484407.03   514471.88   539507.06
# min       45800.00    32246.90    33032.70    34127.50
# 25%       57500.00    89744.45    93772.80    96876.30
# 50%       63200.00   222613.80   233665.30   244662.30
# 75%       75050.00   505822.20   526279.85   542870.20
# max       92300.00  2730973.90  2895101.00  3052645.20
#
# [8 rows x 29 columns]

# %% [markdown]
# ### 2. Use a dictionary comprehension to apply the standard deviation function to each numeric column in the dataframe.

# %%
sd = {'sat17_part': std_dev(combined_sat_act['sat17_part']),
     'sat17_ebrw': std_dev(combined_sat_act['sat17_ebrw']),
     'sat17_math': std_dev(combined_sat_act['sat17_math']),
     'sat17_total': std_dev(combined_sat_act['sat17_total']),
     'act17_part': std_dev(combined_sat_act['act17_part']),
     'act17_eng': std_dev(combined_sat_act['act17_eng']),
     'act17_math': std_dev(combined_sat_act['act17_math']),
     'act17_read': std_dev(combined_sat_act['act17_read']),
     'act17_sci': std_dev(combined_sat_act['act17_sci']),
     'act17_comp': std_dev(combined_sat_act['act17_comp']),
     'sat18_part': std_dev(combined_sat_act['sat18_part']),
     'sat18_ebrw': std_dev(combined_sat_act['sat18_ebrw']),
     'sat18_math': std_dev(combined_sat_act['sat18_math']),
     'sat18_total': std_dev(combined_sat_act['sat18_total']),
     'act18_part': std_dev(combined_sat_act['act18_part']),
     'act18_comp': std_dev(combined_sat_act['act18_comp']),
     'sat19_part': std_dev(combined_sat_act['sat19_part']),
     'sat19_ebrw': std_dev(combined_sat_act['sat19_ebrw']),
     'sat19_math': std_dev(combined_sat_act['sat19_math']),
     'sat19_total': std_dev(combined_sat_act['sat19_total']),
     'act19_part': std_dev(combined_sat_act['act19_part']),
     'act19_comp': std_dev(combined_sat_act['act19_comp'])
     }

sd
# Out:
# {'sat17_part': 0.3492907076664507,
#  'sat17_ebrw': 45.21697020437866,
#  'sat17_math': 46.65713364485503,
#  'sat17_total': 91.58351056778743,
#  'act17_part': 0.3182417575123181,
#  'act17_eng': 2.3304876369363363,
#  'act17_math': 1.9624620273436781,
#  'act17_read': 2.0469029314842646,
#  'act17_sci': 3.151107895464408,
#  'act17_comp': 2.000786081581989,
#  'sat18_part': 0.3694661922353942,
#  'sat18_ebrw': 47.03460978357609,
#  'sat18_math': 47.30194550378352,
#  'sat18_total': 93.22742384464433,
#  'act18_part': 0.33701735820410317,
#  'act18_comp': 2.090779082141178,
#  'sat19_part': 0.3836584048685726,
#  'sat19_ebrw': 45.792378682545134,
#  'sat19_math': 50.78521461840036,
#  'sat19_total': 96.24027185617864,
#  'act19_part': 0.3417582373703047,
#  'act19_comp': 2.172901153595978}

# %% [markdown]
# ### 3. Investigate trends in the dataset

# %% [markdown]
# **How does California state fare for SAT/ ACT against the rest of the states in USA? Crime rate/ household income/ gdp? See if there’s a correlation to the level of participation in SAT & ACT as a whole?**

# %%
#Participation rate for California SAT and ACT 
states_data.loc[(states_data.state == 'California'), ['sat17_part','sat18_part','sat19_part','act17_part','act18_part','act19_part']]
# Out:
#    sat17_part  sat18_part  sat19_part  act17_part  act18_part  act19_part
# 4        0.53         0.6        0.63        0.31        0.27        0.23

# %%
#States GDP for 2017
states_data.sort_values(['gdp_2017'], ascending=False).head(3)
# Out:
#          state  sat17_part  sat17_ebrw  sat17_math  sat17_total  act17_part  \
# 4   California        0.53         531         524         1055        0.31
# 43       Texas        0.62         513         507         1020        0.45
# 32    New York        0.67         528         523         1052        0.31
#
#     act17_eng  act17_math  act17_read  act17_sci  ...  sat19_total  \
# 4        22.5        22.7        23.1       22.2  ...         1065
# 43       19.5        20.7        21.1       20.9  ...         1022
# 32       23.8        24.0        24.6       23.9  ...         1064
#
#     act19_part  act19_comp  poverty_pct  income_2017  income_2018  \
# 4         0.23        22.6         11.4      74900.0      76600.0
# 43        0.39        20.5         12.7      61700.0      61700.0
# 32        0.22        24.5         12.1      67700.0      69100.0
#
#     income_2019   gdp_2017   gdp_2018   gdp_2019
# 4       80400.0  2730973.9  2895101.0  3052645.2
# 43      64000.0  1677110.9  1809706.4  1863953.8
# 32      72100.0  1603903.4  1694957.9  1777751.8
#
# [3 rows x 30 columns]

# %%
#States GDP for 2018
states_data.sort_values(['gdp_2018'], ascending=False).head(3)
# Out:
#          state  sat17_part  sat17_ebrw  sat17_math  sat17_total  act17_part  \
# 4   California        0.53         531         524         1055        0.31
# 43       Texas        0.62         513         507         1020        0.45
# 32    New York        0.67         528         523         1052        0.31
#
#     act17_eng  act17_math  act17_read  act17_sci  ...  sat19_total  \
# 4        22.5        22.7        23.1       22.2  ...         1065
# 43       19.5        20.7        21.1       20.9  ...         1022
# 32       23.8        24.0        24.6       23.9  ...         1064
#
#     act19_part  act19_comp  poverty_pct  income_2017  income_2018  \
# 4         0.23        22.6         11.4      74900.0      76600.0
# 43        0.39        20.5         12.7      61700.0      61700.0
# 32        0.22        24.5         12.1      67700.0      69100.0
#
#     income_2019   gdp_2017   gdp_2018   gdp_2019
# 4       80400.0  2730973.9  2895101.0  3052645.2
# 43      64000.0  1677110.9  1809706.4  1863953.8
# 32      72100.0  1603903.4  1694957.9  1777751.8
#
# [3 rows x 30 columns]

# %%
#States GDP for 2019
states_data.sort_values(['gdp_2019'], ascending=False).head(3)
# Out:
#          state  sat17_part  sat17_ebrw  sat17_math  sat17_total  act17_part  \
# 4   California        0.53         531         524         1055        0.31
# 43       Texas        0.62         513         507         1020        0.45
# 32    New York        0.67         528         523         1052        0.31
#
#     act17_eng  act17_math  act17_read  act17_sci  ...  sat19_total  \
# 4        22.5        22.7        23.1       22.2  ...         1065
# 43       19.5        20.7        21.1       20.9  ...         1022
# 32       23.8        24.0        24.6       23.9  ...         1064
#
#     act19_part  act19_comp  poverty_pct  income_2017  income_2018  \
# 4         0.23        22.6         11.4      74900.0      76600.0
# 43        0.39        20.5         12.7      61700.0      61700.0
# 32        0.22        24.5         12.1      67700.0      69100.0
#
#     income_2019   gdp_2017   gdp_2018   gdp_2019
# 4       80400.0  2730973.9  2895101.0  3052645.2
# 43      64000.0  1677110.9  1809706.4  1863953.8
# 32      72100.0  1603903.4  1694957.9  1777751.8
#
# [3 rows x 30 columns]

# %% [markdown]
# *From above, California state has the highest GDP for 2017, 2018 and 2019.*

# %%
#States median household income for 2019
states_data.sort_values(['income_2019'], ascending=False).head(10)
# Out:
#                    state  poverty_pct  income_2017  income_2018  income_2019  \
# 8   District of Columbia         13.7      85900.0      86700.0      92300.0
# 20              Maryland          7.5      84200.0      84800.0      86700.0
# 30            New Jersey          8.2      83500.0      83200.0      85800.0
# 21         Massachusetts          9.2      80700.0      81300.0      85800.0
# 11                Hawaii          9.4      81100.0      81700.0      83100.0
# 4             California         11.4      74900.0      76600.0      80400.0
# 6            Connecticut          9.7      77400.0      77700.0      78800.0
# 47            Washington          8.8      74000.0      75400.0      78700.0
# 29         New Hampshire          5.6      76500.0      76300.0      77900.0
# 5               Colorado          9.1      72100.0      73300.0      77100.0
#
#      gdp_2017   gdp_2018   gdp_2019
# 8    133391.2   139784.8   144405.7
# 20   400406.0   411099.8   421609.5
# 30   586374.6   613508.7   639436.7
# 21   532354.3   564047.3   593256.7
# 11    87177.8    90276.4    91781.1
# 4   2730973.9  2895101.0  3052645.2
# 6    271582.6   280692.0   288109.1
# 47   519942.9   564480.7   597873.8
# 29    80665.9    83844.0    87507.6
# 5    348898.1   371424.6   392218.0

# %%
#States median household income for 2018
states_data.sort_values(['income_2018'], ascending=False).head(10)
# Out:
#                    state  poverty_pct  income_2017  income_2018  income_2019  \
# 8   District of Columbia         13.7      85900.0      86700.0      92300.0
# 20              Maryland          7.5      84200.0      84800.0      86700.0
# 30            New Jersey          8.2      83500.0      83200.0      85800.0
# 11                Hawaii          9.4      81100.0      81700.0      83100.0
# 21         Massachusetts          9.2      80700.0      81300.0      85800.0
# 6            Connecticut          9.7      77400.0      77700.0      78800.0
# 4             California         11.4      74900.0      76600.0      80400.0
# 29         New Hampshire          5.6      76500.0      76300.0      77900.0
# 1                 Alaska         11.8      76300.0      75700.0      75500.0
# 47            Washington          8.8      74000.0      75400.0      78700.0
#
#      gdp_2017   gdp_2018   gdp_2019
# 8    133391.2   139784.8   144405.7
# 20   400406.0   411099.8   421609.5
# 30   586374.6   613508.7   639436.7
# 11    87177.8    90276.4    91781.1
# 21   532354.3   564047.3   593256.7
# 6    271582.6   280692.0   288109.1
# 4   2730973.9  2895101.0  3052645.2
# 29    80665.9    83844.0    87507.6
# 1     53089.3    54711.7    54547.1
# 47   519942.9   564480.7   597873.8

# %%
#States median household income for 2017
states_data.sort_values(['income_2017'], ascending=False).head(10)
# Out:
#                    state  poverty_pct  income_2017  income_2018  income_2019  \
# 8   District of Columbia         13.7      85900.0      86700.0      92300.0
# 20              Maryland          7.5      84200.0      84800.0      86700.0
# 30            New Jersey          8.2      83500.0      83200.0      85800.0
# 11                Hawaii          9.4      81100.0      81700.0      83100.0
# 21         Massachusetts          9.2      80700.0      81300.0      85800.0
# 6            Connecticut          9.7      77400.0      77700.0      78800.0
# 29         New Hampshire          5.6      76500.0      76300.0      77900.0
# 1                 Alaska         11.8      76300.0      75700.0      75500.0
# 4             California         11.4      74900.0      76600.0      80400.0
# 46              Virginia          9.7      74600.0      73900.0      76500.0
#
#      gdp_2017   gdp_2018   gdp_2019
# 8    133391.2   139784.8   144405.7
# 20   400406.0   411099.8   421609.5
# 30   586374.6   613508.7   639436.7
# 11    87177.8    90276.4    91781.1
# 21   532354.3   564047.3   593256.7
# 6    271582.6   280692.0   288109.1
# 29    80665.9    83844.0    87507.6
# 1     53089.3    54711.7    54547.1
# 4   2730973.9  2895101.0  3052645.2
# 46   509892.8   531757.1   554305.8

# %% [markdown]
# *From above, California state median household income increased from 2017 to 2019, and were in the top 10.*

# %%
#States poverty percentage for 3 year average (2017 - 2019)
states_data.sort_values(['poverty_pct'], ascending=False)
# Out:
#                    state  poverty_pct  income_2017  income_2018  income_2019  \
# 24           Mississippi         19.1      45400.0      45500.0      45800.0
# 18             Louisiana         19.1      48100.0      48800.0      51100.0
# 31            New Mexico         17.2      48800.0      48000.0      51900.0
# 48         West Virginia         15.6      45300.0      44900.0      48900.0
# 3               Arkansas         15.0      47800.0      47900.0      49000.0
# 0                Alabama         14.7      50200.0      50800.0      51700.0
# 40        South Carolina         14.4      52700.0      53300.0      56200.0
# 17              Kentucky         14.2      50500.0      51200.0      52300.0
# 8   District of Columbia         13.7      85900.0      86700.0      92300.0
# 33        North Carolina         13.6      55000.0      54800.0      57300.0
# 10               Georgia         13.3      58600.0      59800.0      62000.0
# 9                Florida         12.9      54900.0      56500.0      59200.0
# 43                 Texas         12.7      61700.0      61700.0      64000.0
# 36              Oklahoma         12.4      52200.0      52900.0      54400.0
# 35                  Ohio         12.4      56300.0      57100.0      58600.0
# 28                Nevada         12.2      60500.0      59700.0      63300.0
# 42             Tennessee         12.1      53500.0      53300.0      56100.0
# 32              New York         12.1      67700.0      69100.0      72100.0
# 2                Arizona         12.1      59000.0      60300.0      62100.0
# 1                 Alaska         11.8      76300.0      75700.0      75500.0
# 19                 Maine         11.5      58700.0      56600.0      58900.0
# 4             California         11.4      74900.0      76600.0      80400.0
# 14               Indiana         11.1      56500.0      56800.0      57600.0
# 25              Missouri         11.0      56000.0      55500.0      57400.0
# 22              Michigan         10.7      57300.0      57700.0      59600.0
# 41          South Dakota         10.6      58900.0      57300.0      59500.0
# 50               Wyoming         10.5      63000.0      62700.0      65000.0
# 38          Pennsylvania         10.5      61700.0      62000.0      63500.0
# 13              Illinois         10.4      65700.0      66200.0      69200.0
# 16                Kansas         10.4      58800.0      59300.0      62100.0
# 27              Nebraska         10.3      62500.0      60600.0      63200.0
# 26               Montana         10.1      55700.0      56300.0      57200.0
# 34          North Dakota         10.1      64500.0      65000.0      64600.0
# 12                 Idaho         10.0      54500.0      56600.0      61000.0
# 39          Rhode Island          9.8      66600.0      65500.0      71200.0
# 37                Oregon          9.8      62800.0      64600.0      67100.0
# 6            Connecticut          9.7      77400.0      77700.0      78800.0
# 46              Virginia          9.7      74600.0      73900.0      76500.0
# 11                Hawaii          9.4      81100.0      81700.0      83100.0
# 21         Massachusetts          9.2      80700.0      81300.0      85800.0
# 5               Colorado          9.1      72100.0      73300.0      77100.0
# 45               Vermont          9.0      60000.0      61900.0      63000.0
# 47            Washington          8.8      74000.0      75400.0      78700.0
# 49             Wisconsin          8.7      61900.0      61900.0      64200.0
# 15                  Iowa          8.6      61100.0      61000.0      61700.0
# 30            New Jersey          8.2      83500.0      83200.0      85800.0
# 7               Delaware          7.6      65600.0      66000.0      70200.0
# 44                  Utah          7.6      71300.0      72700.0      75800.0
# 20              Maryland          7.5      84200.0      84800.0      86700.0
# 23             Minnesota          7.4      71300.0      71600.0      74600.0
# 29         New Hampshire          5.6      76500.0      76300.0      77900.0
#
#      gdp_2017   gdp_2018   gdp_2019
# 24   109962.5   112406.8   114733.8
# 18   241704.2   255810.3   254562.0
# 31    92311.1    97269.2   101971.5
# 48    74799.5    79044.8    79139.7
# 3    122350.2   127306.5   130839.9
# 0    215085.9   224046.9   231171.8
# 40   223044.9   233665.3   244662.3
# 17   201555.0   208250.3   216101.5
# 8    133391.2   139784.8   144405.7
# 33   549670.6   569981.7   595655.4
# 10   574404.4   602340.1   637798.7
# 9   1002568.1  1057862.3  1116435.4
# 43  1677110.9  1809706.4  1863953.8
# 36   190674.5   202466.6   203699.7
# 35   641745.8   666973.9   693199.3
# 28   160785.0   170352.9   181743.3
# 42   349837.7   361381.5   376916.5
# 32  1603903.4  1694957.9  1777751.8
# 2    330416.1   349907.5   369988.2
# 1     53089.3    54711.7    54547.1
# 19    62412.9    65491.9    68452.9
# 4   2730973.9  2895101.0  3052645.2
# 14   353150.3   373518.4   381020.3
# 25   308722.1   319393.9   332272.9
# 22   501751.6   520802.6   531434.6
# 41    50299.4    52404.3    53939.9
# 50    36863.7    39032.3    39600.8
# 38   745011.3   772611.4   799686.2
# 13   827075.2   867535.5   890486.1
# 16   164923.3   172327.5   176738.5
# 27   121946.3   126922.7   131352.4
# 26    48439.5    50903.8    51789.3
# 34    55228.0    59092.6    59004.5
# 12    71688.4    77493.9    82420.1
# 39    57940.8    59129.0    61319.1
# 37   222613.8   237066.0   246647.1
# 6    271582.6   280692.0   288109.1
# 46   509892.8   531757.1   554305.8
# 11    87177.8    90276.4    91781.1
# 21   532354.3   564047.3   593256.7
# 5    348898.1   371424.6   392218.0
# 45    32246.9    33032.7    34127.5
# 47   519942.9   564480.7   597873.8
# 49   318364.2   332263.5   344724.8
# 15   183549.8   190403.1   194322.6
# 30   586374.6   613508.7   639436.7
# 7     68763.8    72488.0    77042.2
# 44   168058.4   182643.6   195088.4
# 20   400406.0   411099.8   421609.5
# 23   354684.2   373419.5   383039.6
# 29    80665.9    83844.0    87507.6

# %%
#States poverty percentile for California
states_data.sort_values(['poverty_pct']).describe()
# Out:
#        poverty_pct   income_2017   income_2018   income_2019      gdp_2017  \
# count    51.000000     51.000000     51.000000     51.000000  5.100000e+01
# mean     11.272549  62819.607843  63137.254902  65513.725490  3.798120e+05
# std       2.828008  10691.660668  10801.869482  11171.016419  4.844070e+05
# min       5.600000  45300.000000  44900.000000  45800.000000  3.224690e+04
# 25%       9.550000  55350.000000  56400.000000  57500.000000  8.974445e+04
# 50%      10.600000  61100.000000  61000.000000  63200.000000  2.226138e+05
# 75%      12.550000  71300.000000  72150.000000  75050.000000  5.058222e+05
# max      19.100000  85900.000000  86700.000000  92300.000000  2.730974e+06
#
#            gdp_2018      gdp_2019
# count  5.100000e+01  5.100000e+01
# mean   4.000477e+05  4.165202e+05
# std    5.144719e+05  5.395071e+05
# min    3.303270e+04  3.412750e+04
# 25%    9.377280e+04  9.687630e+04
# 50%    2.336653e+05  2.446623e+05
# 75%    5.262798e+05  5.428702e+05
# max    2.895101e+06  3.052645e+06

# %%
states_data.sort_values(['act18_comp'], ascending=False).head(3)
# Out:
#             state  sat17_part  sat17_ebrw  sat17_math  sat17_total  \
# 6     Connecticut        1.00         530         512         1041
# 21  Massachusetts        0.76         555         551         1107
# 29  New Hampshire        0.96         532         520         1052
#
#     act17_part  act17_eng  act17_math  act17_read  act17_sci  ...  \
# 6         0.31       25.5        24.6        25.6       24.6  ...
# 21        0.29       25.4        25.3        25.9       24.7  ...
# 29        0.18       25.4        25.1        26.0       24.9  ...
#
#     sat19_total  act19_part  act19_comp  poverty_pct  income_2017  \
# 6          1046        0.22        25.5          9.7      77400.0
# 21         1120        0.21        25.5          9.2      80700.0
# 29         1059        0.14        25.0          5.6      76500.0
#
#     income_2018  income_2019  gdp_2017  gdp_2018  gdp_2019
# 6       77700.0      78800.0  271582.6  280692.0  288109.1
# 21      81300.0      85800.0  532354.3  564047.3  593256.7
# 29      76300.0      77900.0   80665.9   83844.0   87507.6
#
# [3 rows x 30 columns]

# %%
#Tests results for California SAT and ACT 
states_data.loc[(states_data.state == 'California'), ['sat17_total','sat18_total','sat19_total','act17_comp','act18_comp','act19_comp']]
# Out:
#    sat17_total  sat18_total  sat19_total  act17_comp  act18_comp  act19_comp
# 4         1055         1076         1065        22.8        22.7        22.6

# %%
sat19_ca.sort_values(['enroll'], ascending=False).head()
# Out:
#              cds  ccode           cname    enroll  num_tst_takr  num_erw_bm  \
# 1   1.900000e+13   19.0     Los Angeles  114618.0       48676.0     30081.0
# 35  3.700000e+13   37.0       San Diego   42040.0       12872.0     10086.0
# 15  3.000000e+13   30.0          Orange   41235.0       16061.0     11463.0
# 54  3.300000e+13   33.0       Riverside   34277.0       14070.0      8572.0
# 9   3.600000e+13   36.0  San Bernardino   31635.0       10544.0      7014.0
#
#     pct_erw_bm  num_math_bm  pct_math_bm  tot_num_both_bm  pct_both_bm  year
# 1        61.80      19791.0        40.66          18555.0        38.12  2019
# 35       78.36       7462.0        57.97           7146.0        55.52  2019
# 15       71.37       8971.0        55.86           8533.0        53.13  2019
# 54       60.92       5121.0        36.40           4799.0        34.11  2019
# 9        66.52       4368.0        41.43           4083.0        38.72  2019

# %%
#f, ax = plt.subplots(figsize=(6,16))
states_data.plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
# plot a histogram for states GDP
f, ax = plt.subplots(figsize=(20,6))
gdp_states = sns.barplot(x='state',y='gdp_2017',data=states_gdp)
gdp_states.set_xticklabels(states_gdp['state'],rotation=90);
plt.title('States GDP');

# %%
# plot a histogram for states participation rate for 2017
f, ax = plt.subplots(figsize=(20,6))
act17_part_states = sns.barplot(x='state',y='act17_part',data=combined_sat_act)
act17_part_states.set_xticklabels(combined_sat_act['state'],rotation=90);
plt.title('ACT participation rates for 2017');

# %%
# plot a histogram for states participation rate for 2017
f, ax = plt.subplots(figsize=(20,6))
sat17_part_states = sns.barplot(x='state',y='sat17_part',data=combined_sat_act)
sat17_part_states.set_xticklabels(combined_sat_act['state'],rotation=90);
plt.title('SAT participation rates for 2017');

# %%
# plot a histogram for states participation rate for 2018
f, ax = plt.subplots(figsize=(20,6))
act18_part_states = sns.barplot(x='state',y='act18_part',data=combined_sat_act)
act18_part_states.set_xticklabels(combined_sat_act['state'],rotation=90);
plt.title('ACT participation rates for 2018');

# %%
# plot a histogram for states participation rate for 2018
f, ax = plt.subplots(figsize=(20,6))
sat18_part_states = sns.barplot(x='state',y='sat18_part',data=combined_sat_act)
sat18_part_states.set_xticklabels(combined_sat_act['state'],rotation=90);
plt.title('SAT participation rates for 2018');

# %%
# plot a histogram for states participation rate for 2019
f, ax = plt.subplots(figsize=(20,6))
act19_part_states = sns.barplot(x='state',y='act19_part',data=combined_sat_act)
act19_part_states.set_xticklabels(combined_sat_act['state'],rotation=90);
plt.title('ACT participation rates for 2019');

# %%
# plot a histogram for states participation rate for 2019
f, ax = plt.subplots(figsize=(20,6))
sat19_part_states = sns.barplot(x='state',y='sat19_part',data=combined_sat_act)
sat19_part_states.set_xticklabels(combined_sat_act['state'],rotation=90);
plt.title('SAT participation rates for 2019');

# %% [markdown]
# **Which county have the highest enrollment for SAT and ACT in 2019? what is the average.**

# %% [markdown]
# For SAT

# %%
sat19_ca.sort_values(['enroll'], ascending=False).head()
# Out:
#              cds  ccode           cname    enroll  num_tst_takr  num_erw_bm  \
# 1   1.900000e+13   19.0     Los Angeles  114618.0       48676.0     30081.0
# 35  3.700000e+13   37.0       San Diego   42040.0       12872.0     10086.0
# 15  3.000000e+13   30.0          Orange   41235.0       16061.0     11463.0
# 54  3.300000e+13   33.0       Riverside   34277.0       14070.0      8572.0
# 9   3.600000e+13   36.0  San Bernardino   31635.0       10544.0      7014.0
#
#     pct_erw_bm  num_math_bm  pct_math_bm  tot_num_both_bm  pct_both_bm  year
# 1        61.80      19791.0        40.66          18555.0        38.12  2019
# 35       78.36       7462.0        57.97           7146.0        55.52  2019
# 15       71.37       8971.0        55.86           8533.0        53.13  2019
# 54       60.92       5121.0        36.40           4799.0        34.11  2019
# 9        66.52       4368.0        41.43           4083.0        38.72  2019

# %%
sat19_ca['enroll'].mean()
# Out:
# 8442.241379310344

# %% [markdown]
# For ACT

# %%
act19_ca.sort_values(['enroll'], ascending=False).head()
# Out:
#              cds  ccode           cname    enroll  num_tst_takr  avg_scr_read  \
# 57  1.900000e+13   19.0     Los Angeles  114618.0       20678.0          21.0
# 28  3.700000e+13   37.0       San Diego   42040.0        8081.0          24.0
# 25  3.000000e+13   30.0          Orange   41235.0        8501.0          25.0
# 29  3.300000e+13   33.0       Riverside   34277.0        4767.0          21.0
# 37  3.600000e+13   36.0  San Bernardino   31635.0        5418.0          18.0
#
#     avg_scr_eng  avg_scr_math  avg_scr_sci  num_ge_21  pct_ge_21  year
# 57         20.0          21.0         20.0     9182.0      44.40  2019
# 28         23.0          23.0         23.0     5231.0      64.73  2019
# 25         24.0          24.0         24.0     6087.0      71.60  2019
# 29         20.0          20.0         20.0     2144.0      44.98  2019
# 37         17.0          19.0         18.0     1550.0      28.61  2019

# %%
act19_ca['enroll'].mean()
# Out:
# 8442.241379310344

# %% [markdown]
# **Which county have the highest and lowest participation rates for SAT and ACT in 2019? what is the average?**

# %% [markdown]
# For SAT

# %%
#Create a new column for participation rates
sat19_ca['part_rate'] = sat19_ca['num_tst_takr'] / sat19_ca['enroll']

# %%
#Show highest participation rate
sat19_ca.sort_values(['part_rate'], ascending=False).head()
# Out:
#              cds  ccode          cname    enroll  num_tst_takr  num_erw_bm  \
# 57  3.800000e+13   38.0  San Francisco    4447.0        2256.0      1579.0
# 17  4.100000e+13   41.0      San Mateo    7235.0        3113.0      2410.0
# 1   1.900000e+13   19.0    Los Angeles  114618.0       48676.0     30081.0
# 51  5.600000e+13   56.0        Ventura   10750.0        4534.0      2815.0
# 54  3.300000e+13   33.0      Riverside   34277.0       14070.0      8572.0
#
#     pct_erw_bm  num_math_bm  pct_math_bm  tot_num_both_bm  pct_both_bm  year  \
# 57       69.99       1380.0        61.17           1248.0        55.32  2019
# 17       77.42       1945.0        62.48           1857.0        59.65  2019
# 1        61.80      19791.0        40.66          18555.0        38.12  2019
# 51       62.09       2068.0        45.61           1967.0        43.38  2019
# 54       60.92       5121.0        36.40           4799.0        34.11  2019
#
#     part_rate
# 57   0.507308
# 17   0.430270
# 1    0.424680
# 51   0.421767
# 54   0.410479

# %%
#Show lowest participation rate
sat19_ca.sort_values(by='part_rate', ascending=False).tail()
# Out:
#              cds  ccode    cname  enroll  num_tst_takr  num_erw_bm  \
# 36  5.200000e+13   52.0   Tehama   688.0          91.0        69.0
# 29  2.900000e+13   29.0   Nevada  1869.0         186.0       159.0
# 34  2.600000e+13   26.0     Mono   420.0          37.0        32.0
# 37  5.300000e+13   53.0  Trinity   154.0          13.0         NaN
# 31  2.000000e+12    2.0   Alpine     0.0           0.0         NaN
#
#     pct_erw_bm  num_math_bm  pct_math_bm  tot_num_both_bm  pct_both_bm  year  \
# 36       75.82         53.0        58.24             52.0        57.14  2019
# 29       85.48        131.0        70.43            127.0        68.28  2019
# 34       86.49         21.0        56.76             21.0        56.76  2019
# 37         NaN          NaN          NaN              NaN          NaN  2019
# 31         NaN          NaN          NaN              NaN          NaN  2019
#
#     part_rate
# 36   0.132267
# 29   0.099518
# 34   0.088095
# 37   0.084416
# 31        NaN

# %%
#Show the average participation rate
round(sat19_ca['part_rate'].mean(), 2)
# Out:
# 0.26

# %% [markdown]
# For ACT

# %%
#Create a new column for participation rates
act19_ca['part_rate'] = act19_ca['num_tst_takr'] / act19_ca['enroll']

# %%
#Show highest participation rate
act19_ca.sort_values(['part_rate'], ascending=False).head()
# Out:
#              cds  ccode          cname   enroll  num_tst_takr  avg_scr_read  \
# 30  2.500000e+13   25.0          Modoc     87.0          55.0          17.0
# 46  5.200000e+13   52.0         Tehama    688.0         302.0          19.0
# 8   2.100000e+13   21.0          Marin   2647.0         753.0          27.0
# 54  3.800000e+13   38.0  San Francisco   4447.0        1078.0          22.0
# 26  7.000000e+12    7.0   Contra Costa  14593.0        3183.0          25.0
#
#     avg_scr_eng  avg_scr_math  avg_scr_sci  num_ge_21  pct_ge_21  year  \
# 30         15.0          17.0         18.0       11.0      20.00  2019
# 46         18.0          19.0         19.0      105.0      34.77  2019
# 8          26.0          25.0         25.0      606.0      80.48  2019
# 54         21.0          22.0         21.0      565.0      52.41  2019
# 26         25.0          24.0         24.0     2250.0      70.69  2019
#
#     part_rate
# 30   0.632184
# 46   0.438953
# 8    0.284473
# 54   0.242411
# 26   0.218118

# %%
#Show lowest participation rate
act19_ca.sort_values(by='part_rate', ascending=False).tail()
# Out:
#              cds  ccode      cname  enroll  num_tst_takr  avg_scr_read  \
# 6   2.600000e+13   26.0       Mono   420.0          20.0          26.0
# 31  5.500000e+13   55.0   Tuolumne   518.0          23.0          26.0
# 56  2.900000e+13   29.0     Nevada  1869.0          76.0          25.0
# 41  8.000000e+12    8.0  Del Norte   363.0           5.0           NaN
# 39  2.000000e+12    2.0     Alpine     0.0           0.0           NaN
#
#     avg_scr_eng  avg_scr_math  avg_scr_sci  num_ge_21  pct_ge_21  year  \
# 6          24.0          24.0         24.0       16.0      80.00  2019
# 31         23.0          23.0         23.0       18.0      78.26  2019
# 56         24.0          24.0         24.0       57.0      75.00  2019
# 41          NaN           NaN          NaN        NaN        NaN  2019
# 39          NaN           NaN          NaN        NaN        NaN  2019
#
#     part_rate
# 6    0.047619
# 31   0.044402
# 56   0.040663
# 41   0.013774
# 39        NaN

# %%
#Show the average participation rate
round(act19_ca['part_rate'].mean(), 2)
# Out:
# 0.15

# %% [markdown]
# **Do any county show have >50% participation on both tests in 2019?**

# %% [markdown]
# None

# %%
#Average participation rate for other states
round(combined_sat_act['sat17_part'].mean(), 2)
# Out:
# 0.4

# %%
round(combined_sat_act['sat18_part'].mean(), 2)
# Out:
# 0.46

# %%
round(combined_sat_act['sat19_part'].mean(), 2)
# Out:
# 0.49

# %%
round(combined_sat_act['act17_part'].mean(), 2)
# Out:
# 0.65

# %%
round(combined_sat_act['act18_part'].mean(), 2)
# Out:
# 0.62

# %%
round(combined_sat_act['act19_part'].mean(), 2)
# Out:
# 0.59

# %% [markdown]
# **a) Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?**

# %% [markdown]
# For 2017

# %%
combined_sat_act.sort_values(['sat17_part'], ascending=False).head()
# Out:
#                    state  sat17_part  sat17_ebrw  sat17_math  sat17_total  \
# 8   District of Columbia        1.00         482         468          950
# 22              Michigan        1.00         509         495         1005
# 6            Connecticut        1.00         530         512         1041
# 7               Delaware        1.00         503         492          996
# 29         New Hampshire        0.96         532         520         1052
#
#     act17_part  act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 8         0.32       24.4        23.5        24.9       23.5  ...         480
# 22        0.29       24.1        23.7        24.5       23.8  ...         499
# 6         0.31       25.5        24.6        25.6       24.6  ...         519
# 7         0.18       24.1        23.4        24.8       23.6  ...         492
# 29        0.18       25.4        25.1        26.0       24.9  ...         528
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 8           977        0.32        23.6        0.94         495         480
# 22         1011        0.22        24.2        1.00         507         496
# 6          1053        0.26        25.6        1.00         529         516
# 7           998        0.17        23.8        1.00         499         486
# 29         1063        0.16        25.1        0.95         533         526
#
#     sat19_total  act19_part  act19_comp
# 8           975        0.32        23.5
# 22         1003        0.19        24.4
# 6          1046        0.22        25.5
# 7           985        0.13        24.1
# 29         1059        0.14        25.0
#
# [5 rows x 23 columns]

# %%
combined_sat_act.sort_values(['sat17_part'], ascending=False).tail()
# Out:
#            state  sat17_part  sat17_ebrw  sat17_math  sat17_total  act17_part  \
# 3       Arkansas        0.03         614         594         1208        1.00
# 50       Wyoming        0.03         626         604         1230        1.00
# 34  North Dakota        0.02         635         621         1256        0.98
# 24   Mississippi        0.02         634         607         1242        1.00
# 15          Iowa        0.02         641         635         1275        0.67
#
#     act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 3        18.9        19.0        19.7       19.5  ...         576
# 50       19.4        19.8        20.8       20.6  ...         625
# 34       19.0        20.4        20.5       20.6  ...         643
# 24       18.2        18.1        18.8       18.8  ...         606
# 15       21.2        21.3        22.6       22.1  ...         631
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 3          1169        1.00        19.4        0.06         582         559
# 50         1257        1.00        20.0        0.03         623         615
# 34         1283        0.98        20.3        0.02         627         636
# 24         1236        1.00        18.6        0.03         628         608
# 15         1265        0.68        21.8        0.03         622         622
#
#     sat19_total  act19_part  act19_comp
# 3          1141        1.00        19.3
# 50         1238        1.00        19.8
# 34         1263        0.96        19.9
# 24         1237        1.00        18.4
# 15         1244        0.66        21.6
#
# [5 rows x 23 columns]

# %%
combined_sat_act.sort_values(['act17_part'], ascending=False).head(3)
# Out:
#         state  sat17_part  sat17_ebrw  sat17_math  sat17_total  act17_part  \
# 0     Alabama        0.05         593         572         1165         1.0
# 17   Kentucky        0.04         631         616         1247         1.0
# 49  Wisconsin        0.03         642         649         1291         1.0
#
#     act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 0        18.9        18.4        19.7       19.4  ...         571
# 17       19.6        19.4        20.5       20.1  ...         618
# 49       19.7        20.4        20.6       20.9  ...         653
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 0          1166         1.0        19.1        0.07         583         560
# 17         1248         1.0        20.2        0.04         620         612
# 49         1294         1.0        20.5        0.03         635         648
#
#     sat19_total  act19_part  act19_comp
# 0          1143         1.0        18.9
# 17         1232         1.0        19.8
# 49         1283         1.0        20.3
#
# [3 rows x 23 columns]

# %%
combined_sat_act.sort_values(['act17_part'], ascending=False).tail(3)
# Out:
#             state  sat17_part  sat17_ebrw  sat17_math  sat17_total  \
# 7        Delaware        1.00         503         492          996
# 29  New Hampshire        0.96         532         520         1052
# 19          Maine        0.95         513         499         1012
#
#     act17_part  act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 7         0.18       24.1        23.4        24.8       23.6  ...         492
# 29        0.18       25.4        25.1        26.0       24.9  ...         528
# 19        0.08       24.2        24.0        24.8       23.7  ...         501
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 7           998        0.17        23.8        1.00         499         486
# 29         1063        0.16        25.1        0.95         533         526
# 19         1013        0.07        24.0        0.99         512         502
#
#     sat19_total  act19_part  act19_comp
# 7           985        0.13        24.1
# 29         1059        0.14        25.0
# 19         1013        0.06        24.3
#
# [3 rows x 23 columns]

# %% [markdown]
# For 2018

# %%
combined_sat_act.sort_values(['sat18_part']).head(3)
# Out:
#            state  sat17_part  sat17_ebrw  sat17_math  sat17_total  act17_part  \
# 35  North Dakota        0.02         635         621         1256        0.98
# 25   Mississippi        0.02         634         607         1242        1.00
# 42  South Dakota        0.03         612         603         1216        0.80
#
#     act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 35       19.0        20.4        20.5       20.6  ...         643
# 25       18.2        18.1        18.8       18.8  ...         606
# 42       20.7        21.5        22.3       22.0  ...         618
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 35         1283      0.0098        20.3        0.02         627         636
# 25         1236      0.0100        18.6        0.03         628         608
# 42         1240      0.0080        21.9        0.03         633         635
#
#     sat19_total  act19_part  act19_comp
# 35         1263        0.96        19.9
# 25         1237        1.00        18.4
# 42         1268        0.75        21.6
#
# [3 rows x 23 columns]

# %%
combined_sat_act.sort_values(['sat18_part']).tail(3)
# Out:
#        state  sat17_part  sat17_ebrw  sat17_math  sat17_total  act17_part  \
# 5   Colorado        0.11         606         595         1201        1.00
# 23  Michigan        1.00         509         495         1005        0.29
# 7   Delaware        1.00         503         492          996        0.18
#
#     act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 5        20.1        20.3        21.2       20.9  ...         506
# 23       24.1        23.7        24.5       23.8  ...         499
# 7        24.1        23.4        24.8       23.6  ...         492
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 5          1025      0.0031        23.9         1.0         518         506
# 23         1011      0.0029        24.2         1.0         507         496
# 7           998      0.0031        23.8         1.0         499         486
#
#     sat19_total  act19_part  act19_comp
# 5          1024        0.27        23.8
# 23         1003        0.19        24.4
# 7           985        0.13        24.1
#
# [3 rows x 23 columns]

# %%
combined_sat_act.sort_values(['act18_part']).head(3)
# Out:
#                    state  sat17_part  sat17_ebrw  sat17_math  sat17_total  \
# 20                 Maine        0.95         513         499         1012
# 30         New Hampshire        0.96         532         520         1052
# 8   District of Columbia        1.00         482         468          950
#
#     act17_part  act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 20        0.08       24.2        24.0        24.8       23.7  ...         501
# 30        0.18       25.4        25.1        26.0       24.9  ...         528
# 8         0.32       24.4        23.5        24.9       23.5  ...         480
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 20         1013      0.0008        24.0        0.99         512         502
# 30         1063      0.0018        25.1        0.95         533         526
# 8           977      0.0018        23.6        0.94         495         480
#
#     sat19_total  act19_part  act19_comp
# 20         1013        0.06        24.3
# 30         1059        0.14        25.0
# 8           975        0.32        23.5
#
# [3 rows x 23 columns]

# %%
combined_sat_act.sort_values(['act18_part']).tail(3)
# Out:
#        state  sat17_part  sat17_ebrw  sat17_math  sat17_total  act17_part  \
# 1     Alaska        0.38         547         533         1080        0.65
# 37  Oklahoma        0.07         530         517         1047        1.00
# 51   Wyoming        0.03         626         604         1230        1.00
#
#     act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 1        18.7        19.8        20.4       19.9  ...         544
# 37       18.5        18.8        20.1       19.6  ...         521
# 51       19.4        19.8        20.8       20.6  ...         625
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 1          1106        0.01        20.8        0.41         556         541
# 37         1062        0.01        19.3        0.22         490         472
# 51         1257        0.01        20.0        0.03         623         615
#
#     sat19_total  act19_part  act19_comp
# 1          1097        0.38        20.1
# 37          963        1.00        18.9
# 51         1238        1.00        19.8
#
# [3 rows x 23 columns]

# %% [markdown]
# For 2019

# %%
combined_sat_act.sort_values(['sat19_part']).head(3)
# Out:
#            state  sat17_part  sat17_ebrw  sat17_math  sat17_total  act17_part  \
# 35  North Dakota        0.02         635         621         1256        0.98
# 25   Mississippi        0.02         634         607         1242        1.00
# 42  South Dakota        0.03         612         603         1216        0.80
#
#     act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 35       19.0        20.4        20.5       20.6  ...         643
# 25       18.2        18.1        18.8       18.8  ...         606
# 42       20.7        21.5        22.3       22.0  ...         618
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 35         1283      0.0098        20.3        0.02         627         636
# 25         1236      0.0100        18.6        0.03         628         608
# 42         1240      0.0080        21.9        0.03         633         635
#
#     sat19_total  act19_part  act19_comp
# 35         1263        0.96        19.9
# 25         1237        1.00        18.4
# 42         1268        0.75        21.6
#
# [3 rows x 23 columns]

# %%
combined_sat_act.sort_values(['sat19_part']).tail(3)
# Out:
#            state  sat17_part  sat17_ebrw  sat17_math  sat17_total  act17_part  \
# 23      Michigan        1.00         509         495         1005        0.29
# 40  Rhode Island        0.71         539         524         1062        0.21
# 7       Delaware        1.00         503         492          996        0.18
#
#     act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 23       24.1        23.7        24.5       23.8  ...         499
# 40       24.0        23.3        24.7       23.4  ...         505
# 7        24.1        23.4        24.8       23.6  ...         492
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 23         1011      0.0029        24.2         1.0         507         496
# 40         1018      0.0021        24.2         1.0         503         492
# 7           998      0.0031        23.8         1.0         499         486
#
#     sat19_total  act19_part  act19_comp
# 23         1003        0.19        24.4
# 40          995        0.12        24.7
# 7           985        0.13        24.1
#
# [3 rows x 23 columns]

# %%
combined_sat_act.sort_values(['act19_part']).head(3)
# Out:
#            state  sat17_part  sat17_ebrw  sat17_math  sat17_total  act17_part  \
# 19         Maine        0.95         513         499         1012        0.08
# 20         Maine        0.95         513         499         1012        0.08
# 40  Rhode Island        0.71         539         524         1062        0.21
#
#     act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 19       24.2        24.0        24.8       23.7  ...         501
# 20       24.2        24.0        24.8       23.7  ...         501
# 40       24.0        23.3        24.7       23.4  ...         505
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 19         1013      0.0100        24.0        0.99         512         502
# 20         1013      0.0008        24.0        0.99         512         502
# 40         1018      0.0021        24.2        1.00         503         492
#
#     sat19_total  act19_part  act19_comp
# 19         1013        0.06        24.3
# 20         1013        0.06        24.3
# 40          995        0.12        24.7
#
# [3 rows x 23 columns]

# %%
combined_sat_act.sort_values(['act19_part']).tail(3)
# Out:
#        state  sat17_part  sat17_ebrw  sat17_math  sat17_total  act17_part  \
# 3   Arkansas        0.03         614         594         1208         1.0
# 37  Oklahoma        0.07         530         517         1047         1.0
# 51   Wyoming        0.03         626         604         1230         1.0
#
#     act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 3        18.9        19.0        19.7       19.5  ...         576
# 37       18.5        18.8        20.1       19.6  ...         521
# 51       19.4        19.8        20.8       20.6  ...         625
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 3          1169      0.0062        19.4        0.06         582         559
# 37         1062      0.0100        19.3        0.22         490         472
# 51         1257      0.0100        20.0        0.03         623         615
#
#     sat19_total  act19_part  act19_comp
# 3          1141         1.0        19.3
# 37          963         1.0        18.9
# 51         1238         1.0        19.8
#
# [3 rows x 23 columns]

# %% [markdown]
# **b) Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?**

# %% [markdown]
# For 2017

# %%
combined_sat_act.sort_values(['sat17_total'], ascending=False).head(3)
# Out:
#         state  sat17_part  sat17_ebrw  sat17_math  sat17_total  act17_part  \
# 23  Minnesota        0.03         644         651         1295        1.00
# 49  Wisconsin        0.03         642         649         1291        1.00
# 15       Iowa        0.02         641         635         1275        0.67
#
#     act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 23       20.4        21.5        21.8       21.6  ...         655
# 49       19.7        20.4        20.6       20.9  ...         653
# 15       21.2        21.3        22.6       22.1  ...         631
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 23         1298        0.99        21.3        0.04         636         648
# 49         1294        1.00        20.5        0.03         635         648
# 15         1265        0.68        21.8        0.03         622         622
#
#     sat19_total  act19_part  act19_comp
# 23         1284        0.95        21.4
# 49         1283        1.00        20.3
# 15         1244        0.66        21.6
#
# [3 rows x 23 columns]

# %%
combined_sat_act.sort_values(['sat17_total'], ascending=False).tail(3)
# Out:
#                    state  sat17_part  sat17_ebrw  sat17_math  sat17_total  \
# 22              Michigan         1.0         509         495         1005
# 7               Delaware         1.0         503         492          996
# 8   District of Columbia         1.0         482         468          950
#
#     act17_part  act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 22        0.29       24.1        23.7        24.5       23.8  ...         499
# 7         0.18       24.1        23.4        24.8       23.6  ...         492
# 8         0.32       24.4        23.5        24.9       23.5  ...         480
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 22         1011        0.22        24.2        1.00         507         496
# 7           998        0.17        23.8        1.00         499         486
# 8           977        0.32        23.6        0.94         495         480
#
#     sat19_total  act19_part  act19_comp
# 22         1003        0.19        24.4
# 7           985        0.13        24.1
# 8           975        0.32        23.5
#
# [3 rows x 23 columns]

# %%
combined_sat_act.sort_values(['act17_comp']).head(3)
# Out:
#              state  sat17_part  sat17_ebrw  sat17_math  sat17_total  \
# 29          Nevada        0.26         563         553         1116
# 25     Mississippi        0.02         634         607         1242
# 41  South Carolina        0.50         543         521         1064
#
#     act17_part  act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 29         1.0       16.3        18.0        18.1       18.2  ...         566
# 25         1.0       18.2        18.1        18.8       18.8  ...         606
# 41         1.0       17.5        18.6        19.1       18.9  ...         523
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 29         1140        0.01        17.7        0.20         580         576
# 25         1236        0.01        18.6        0.03         628         608
# 41         1070        0.01        18.3        0.68         526         504
#
#     sat19_total  act19_part  act19_comp
# 29         1156        1.00        17.9
# 25         1237        1.00        18.4
# 41         1030        0.78        18.8
#
# [3 rows x 23 columns]

# %%
combined_sat_act.sort_values(['act17_comp']).tail(3)
# Out:
#             state  sat17_part  sat17_ebrw  sat17_math  sat17_total  \
# 6     Connecticut        1.00         530         512         1041
# 22  Massachusetts        0.76         555         551         1107
# 30  New Hampshire        0.96         532         520         1052
#
#     act17_part  act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 6         0.31       25.5        24.6        25.6       24.6  ...         519
# 22        0.29       25.4        25.3        25.9       24.7  ...         563
# 30        0.18       25.4        25.1        26.0       24.9  ...         528
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 6          1053      0.0100        25.6        1.00         529         516
# 22         1125      0.0029        25.5        0.81         559         561
# 30         1063      0.0018        25.1        0.95         533         526
#
#     sat19_total  act19_part  act19_comp
# 6          1046        0.22        25.5
# 22         1120        0.21        25.5
# 30         1059        0.14        25.0
#
# [3 rows x 23 columns]

# %% [markdown]
# For 2018

# %%
combined_sat_act.sort_values(['sat18_total']).head(3)
# Out:
#                    state  sat17_part  sat17_ebrw  sat17_math  sat17_total  \
# 8   District of Columbia        1.00         482         468          950
# 7               Delaware        1.00         503         492          996
# 49         West Virginia        0.14         558         528         1086
#
#     act17_part  act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 8         0.32       24.4        23.5        24.9       23.5  ...         480
# 7         0.18       24.1        23.4        24.8       23.6  ...         492
# 49        0.69       20.0        19.4        21.2       20.5  ...         486
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 8           977      0.0018        23.6        0.94         495         480
# 7           998      0.0031        23.8        1.00         499         486
# 49          999      0.0069        20.3        0.99         483         460
#
#     sat19_total  act19_part  act19_comp
# 8           975        0.32        23.5
# 7           985        0.13        24.1
# 49          943        0.49        20.8
#
# [3 rows x 23 columns]

# %%
combined_sat_act.sort_values(['sat18_total']).tail(3)
# Out:
#            state  sat17_part  sat17_ebrw  sat17_math  sat17_total  act17_part  \
# 35  North Dakota        0.02         635         621         1256        0.98
# 50     Wisconsin        0.03         642         649         1291        1.00
# 24     Minnesota        0.03         644         651         1295        1.00
#
#     act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 35       19.0        20.4        20.5       20.6  ...         643
# 50       19.7        20.4        20.6       20.9  ...         653
# 24       20.4        21.5        21.8       21.6  ...         655
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 35         1283      0.0098        20.3        0.02         627         636
# 50         1294      0.0100        20.5        0.03         635         648
# 24         1298      0.0100        21.3        0.04         636         648
#
#     sat19_total  act19_part  act19_comp
# 35         1263        0.96        19.9
# 50         1283        1.00        20.3
# 24         1284        0.95        21.4
#
# [3 rows x 23 columns]

# %%
combined_sat_act.sort_values(['act18_comp']).head(3)
# Out:
#              state  sat17_part  sat17_ebrw  sat17_math  sat17_total  \
# 29          Nevada        0.26         563         553         1116
# 41  South Carolina        0.50         543         521         1064
# 25     Mississippi        0.02         634         607         1242
#
#     act17_part  act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 29         1.0       16.3        18.0        18.1       18.2  ...         566
# 41         1.0       17.5        18.6        19.1       18.9  ...         523
# 25         1.0       18.2        18.1        18.8       18.8  ...         606
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 29         1140        0.01        17.7        0.20         580         576
# 41         1070        0.01        18.3        0.68         526         504
# 25         1236        0.01        18.6        0.03         628         608
#
#     sat19_total  act19_part  act19_comp
# 29         1156        1.00        17.9
# 41         1030        0.78        18.8
# 25         1237        1.00        18.4
#
# [3 rows x 23 columns]

# %%
combined_sat_act.sort_values(['act18_comp']).tail(3)
# Out:
#             state  sat17_part  sat17_ebrw  sat17_math  sat17_total  \
# 30  New Hampshire        0.96         532         520         1052
# 22  Massachusetts        0.76         555         551         1107
# 6     Connecticut        1.00         530         512         1041
#
#     act17_part  act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 30        0.18       25.4        25.1        26.0       24.9  ...         528
# 22        0.29       25.4        25.3        25.9       24.7  ...         563
# 6         0.31       25.5        24.6        25.6       24.6  ...         519
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 30         1063      0.0018        25.1        0.95         533         526
# 22         1125      0.0029        25.5        0.81         559         561
# 6          1053      0.0100        25.6        1.00         529         516
#
#     sat19_total  act19_part  act19_comp
# 30         1059        0.14        25.0
# 22         1120        0.21        25.5
# 6          1046        0.22        25.5
#
# [3 rows x 23 columns]

# %% [markdown]
# For 2019

# %%
combined_sat_act.sort_values(['sat19_total']).head(3)
# Out:
#                    state  sat17_part  sat17_ebrw  sat17_math  sat17_total  \
# 49         West Virginia        0.14         558         528         1086
# 37              Oklahoma        0.07         530         517         1047
# 8   District of Columbia        1.00         482         468          950
#
#     act17_part  act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 49        0.69       20.0        19.4        21.2       20.5  ...         486
# 37        1.00       18.5        18.8        20.1       19.6  ...         521
# 8         0.32       24.4        23.5        24.9       23.5  ...         480
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 49          999      0.0069        20.3        0.99         483         460
# 37         1062      0.0100        19.3        0.22         490         472
# 8           977      0.0018        23.6        0.94         495         480
#
#     sat19_total  act19_part  act19_comp
# 49          943        0.49        20.8
# 37          963        1.00        18.9
# 8           975        0.32        23.5
#
# [3 rows x 23 columns]

# %%
combined_sat_act.sort_values(['sat19_total']).tail(3)
# Out:
#            state  sat17_part  sat17_ebrw  sat17_math  sat17_total  act17_part  \
# 42  South Dakota        0.03         612         603         1216         0.8
# 50     Wisconsin        0.03         642         649         1291         1.0
# 24     Minnesota        0.03         644         651         1295         1.0
#
#     act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 42       20.7        21.5        22.3       22.0  ...         618
# 50       19.7        20.4        20.6       20.9  ...         653
# 24       20.4        21.5        21.8       21.6  ...         655
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 42         1240       0.008        21.9        0.03         633         635
# 50         1294       0.010        20.5        0.03         635         648
# 24         1298       0.010        21.3        0.04         636         648
#
#     sat19_total  act19_part  act19_comp
# 42         1268        0.75        21.6
# 50         1283        1.00        20.3
# 24         1284        0.95        21.4
#
# [3 rows x 23 columns]

# %%
combined_sat_act.sort_values(['act19_comp']).head(3)
# Out:
#              state  sat17_part  sat17_ebrw  sat17_math  sat17_total  \
# 29          Nevada        0.26         563         553         1116
# 25     Mississippi        0.02         634         607         1242
# 41  South Carolina        0.50         543         521         1064
#
#     act17_part  act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 29         1.0       16.3        18.0        18.1       18.2  ...         566
# 25         1.0       18.2        18.1        18.8       18.8  ...         606
# 41         1.0       17.5        18.6        19.1       18.9  ...         523
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 29         1140        0.01        17.7        0.20         580         576
# 25         1236        0.01        18.6        0.03         628         608
# 41         1070        0.01        18.3        0.68         526         504
#
#     sat19_total  act19_part  act19_comp
# 29         1156        1.00        17.9
# 25         1237        1.00        18.4
# 41         1030        0.78        18.8
#
# [3 rows x 23 columns]

# %%
combined_sat_act.sort_values(['act19_comp']).tail(3)
# Out:
#             state  sat17_part  sat17_ebrw  sat17_math  sat17_total  \
# 30  New Hampshire        0.96         532         520         1052
# 22  Massachusetts        0.76         555         551         1107
# 6     Connecticut        1.00         530         512         1041
#
#     act17_part  act17_eng  act17_math  act17_read  act17_sci  ...  sat18_math  \
# 30        0.18       25.4        25.1        26.0       24.9  ...         528
# 22        0.29       25.4        25.3        25.9       24.7  ...         563
# 6         0.31       25.5        24.6        25.6       24.6  ...         519
#
#     sat18_total  act18_part  act18_comp  sat19_part  sat19_ebrw  sat19_math  \
# 30         1063      0.0018        25.1        0.95         533         526
# 22         1125      0.0029        25.5        0.81         559         561
# 6          1053      0.0100        25.6        1.00         529         516
#
#     sat19_total  act19_part  act19_comp
# 30         1059        0.14        25.0
# 22         1120        0.21        25.5
# 6          1046        0.22        25.5
#
# [3 rows x 23 columns]

# %% [markdown]
# **c) Do any states with 100% participation on a given test have a rate change year-to-year?**

# %% [markdown]
# **d) Do any states show have >50% participation on *both* tests each year?**

# %% [markdown]
# **e) Which colleges have the highest median SAT and ACT scores for admittance?**

# %% [markdown]
# **f) Which California school districts have the highest and lowest mean test scores?**

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
fig, ax = plt.subplots(figsize=(13,7))
title = "Correlation of states GDP, income and poverty"
sns.heatmap(merged_states_info.corr(), annot = True, cmap = 'coolwarm');

# %%
plt.figure(figsize=(15, 15))
plt.title('Correlation of all data from SAT and ACT 2017-19', size=16)
sns.heatmap(states_data.corr(), annot = True, cmap = 'coolwarm');

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **To-Do:** *Edit this cell with your conclusions and recommendations.*

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
